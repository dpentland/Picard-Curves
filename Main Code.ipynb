# %%
def printLpolys(ret,C):
    for r in ret:
        p,coeffs,Lpoly = r[1],r[0],r[2]
        print "             prime: ", p
        print "L polynomial mod p: ", coeffs
        print "      L polynomial: ", Lpoly
        print "_______________________________________"
        
path = 'C:\Users\Dylan\Downloads\hwlpolys.txt' 
#Sample data files are provided in "randomCurveData".
#These data files contain a list of L polynomials modulo p.
        
#Format: path, curve, lower bound, upper bound
ret = findLpolys(path,1000,4000)
printLpolys(ret,C)
# Out:
# =======================================
# Data for the curve y^3 = x^4 +  0 x^2 +  1 x +  1
# =======================================
# starting
# done in 80.5861980915 seconds
# average time 0.210407827915 seconds
#              prime:  1009
# L polynomial mod p:  [1, 80, 275, 293]
#       L polynomial:  [1, 80, 1284, -15851, 1295556, 81446480, 1027243729]
# _______________________________________
#              prime:  1013
# L polynomial mod p:  [1, 0, 227, 0]
#       L polynomial:  [1, 0, 2253, 0, 2282289, 0, 1039509197]
# _______________________________________
#              prime:  1019
# L polynomial mod p:  [1, 0, -364, 0]
#       L polynomial:  [1, 0, 1674, 0, 1705806, 0, 1058089859]
# _______________________________________
#              prime:  1021
# L polynomial mod p:  [1, -32, -244, 339]
#       L polynomial:  [1, -32, -244, 16675, -249124, -33358112, 1064332261]
# _______________________________________
#              prime:  1031
# L polynomial mod p:  [1, 0, -256, 0]
#       L polynomial:  [1, 0, 775, 0, 799025, 0, 1095912791]
# _______________________________________
#              prime:  1033
# L polynomial mod p:  [1, 55, 492, -229]
#       L polynomial:  [1, 55, 2558, 107203, 2642414, 58689895, 1102302937]
# _______________________________________
#              prime:  1039
# L polynomial mod p:  [1, -5, -220, 122]
#       L polynomial:  [1, -5, -220, -25853, -228580, -5397605, 1121622319]
# _______________________________________
#              prime:  1049
# L polynomial mod p:  [1, 0, -295, 0]
#       L polynomial:  [1, 0, 754, 0, 790946, 0, 1154320649]
# _______________________________________
#              prime:  1051
# L polynomial mod p:  [1, -40, -235, 176]
#       L polynomial:  [1, -40, 2918, -78649, 3066818, -44184040, 1160935651]
# _______________________________________
#              prime:  1061
# L polynomial mod p:  [1, 0, 99, 0]
#       L polynomial:  [1, 0, 99, 0, 105039, 0, 1194389981]
# _______________________________________
#              prime:  1063
# L polynomial mod p:  [1, -16, 279, -273]
#       L polynomial:  [1, -16, -784, 46499, -833392, -18079504, 1201157047]
# _______________________________________
#              prime:  1069
# L polynomial mod p:  [1, -60, -408, 304]
#       L polynomial:  [1, -60, -408, 86893, -436152, -68565660, 1221611509]
# _______________________________________
#              prime:  1087
# L polynomial mod p:  [1, 63, -435, 189]
#       L polynomial:  [1, 63, 2826, 89323, 3071862, 74438847, 1284365503]
# _______________________________________
#              prime:  1091
# L polynomial mod p:  [1, 0, 130, 0]
#       L polynomial:  [1, 0, 1221, 0, 1332111, 0, 1298596571]
# _______________________________________
#              prime:  1093
# L polynomial mod p:  [1, -5, -190, 532]
#       L polynomial:  [1, -5, -190, -22421, -207670, -5973245, 1305751357]
# _______________________________________
#              prime:  1097
# L polynomial mod p:  [1, 0, 513, 0]
#       L polynomial:  [1, 0, 513, 0, 562761, 0, 1320139673]
# _______________________________________
#              prime:  1103
# L polynomial mod p:  [1, 0, 4, 0]
#       L polynomial:  [1, 0, 1107, 0, 1221021, 0, 1341919727]
# _______________________________________
#              prime:  1109
# L polynomial mod p:  [1, 0, 119, 0]
#       L polynomial:  [1, 0, 2337, 0, 2591733, 0, 1363938029]
# _______________________________________
#              prime:  1117
# L polynomial mod p:  [1, -22, -115, -94]
#       L polynomial:  [1, -22, 1002, -1211, 1119234, -27449158, 1393668613]
# _______________________________________
#              prime:  1123
# L polynomial mod p:  [1, 49, 358, 336]
#       L polynomial:  [1, 49, 1481, 51994, 1663163, 61795321, 1416247867]
# _______________________________________
#              prime:  1129
# L polynomial mod p:  [1, 30, 113, -511]
#       L polynomial:  [1, 30, 1242, 86422, 1402218, 38239230, 1439069689]
# _______________________________________
#              prime:  1151
# L polynomial mod p:  [1, 0, 209, 0]
#       L polynomial:  [1, 0, 2511, 0, 2890161, 0, 1524845951]
# _______________________________________
#              prime:  1153
# L polynomial mod p:  [1, -53, -412, 161]
#       L polynomial:  [1, -53, -412, 85483, -475036, -70458677, 1532808577]
# _______________________________________
#              prime:  1163
# L polynomial mod p:  [1, 0, 108, 0]
#       L polynomial:  [1, 0, 108, 0, 125604, 0, 1573037747]
# _______________________________________
#              prime:  1171
# L polynomial mod p:  [1, 48, -558, 525]
#       L polynomial:  [1, 48, -558, -72077, -653418, 65819568, 1605723211]
# _______________________________________
#              prime:  1181
# L polynomial mod p:  [1, 0, 404, 0]
#       L polynomial:  [1, 0, 2766, 0, 3266646, 0, 1647212741]
# _______________________________________
#              prime:  1187
# L polynomial mod p:  [1, 0, -388, 0]
#       L polynomial:  [1, 0, 1986, 0, 2357382, 0, 1672446203]
# _______________________________________
#              prime:  1193
# L polynomial mod p:  [1, 0, -507, 0]
#       L polynomial:  [1, 0, -507, 0, -604851, 0, 1697936057]
# _______________________________________
#              prime:  1201
# L polynomial mod p:  [1, 96, -413, -7]
#       L polynomial:  [1, 96, 5592, 236590, 6715992, 138470496, 1732323601]
# _______________________________________
#              prime:  1213
# L polynomial mod p:  [1, 33, 211, -41]
#       L polynomial:  [1, 33, -1002, -65543, -1215426, 48555177, 1784770597]
# _______________________________________
#              prime:  1217
# L polynomial mod p:  [1, 0, 414, 0]
#       L polynomial:  [1, 0, 2848, 0, 3466016, 0, 1802485313]
# _______________________________________
#              prime:  1223
# L polynomial mod p:  [1, 0, -447, 0]
#       L polynomial:  [1, 0, -447, 0, -546681, 0, 1829276567]
# _______________________________________
#              prime:  1229
# L polynomial mod p:  [1, 0, 99, 0]
#       L polynomial:  [1, 0, 99, 0, 121671, 0, 1856331989]
# _______________________________________
#              prime:  1231
# L polynomial mod p:  [1, -37, -610, 544]
#       L polynomial:  [1, -37, 621, -6842, 764451, -56068357, 1865409391]
# _______________________________________
#              prime:  1237
# L polynomial mod p:  [1, 59, -452, 245]
#       L polynomial:  [1, 59, 2022, 76939, 2501214, 90279971, 1892819053]
# _______________________________________
#              prime:  1249
# L polynomial mod p:  [1, 14, 3, 42]
#       L polynomial:  [1, 14, -1246, -34930, -1556254, 21840014, 1948441249]
# _______________________________________
#              prime:  1259
# L polynomial mod p:  [1, 0, -3, 0]
#       L polynomial:  [1, 0, -3, 0, -3777, 0, 1995616979]
# _______________________________________
#              prime:  1277
# L polynomial mod p:  [1, 0, 153, 0]
#       L polynomial:  [1, 0, 153, 0, 195381, 0, 2082440933]
# _______________________________________
#              prime:  1279
# L polynomial mod p:  [1, -27, 610, 113]
#       L polynomial:  [1, -27, 3168, -51047, 4051872, -44167707, 2092240639]
# _______________________________________
#              prime:  1283
# L polynomial mod p:  [1, 0, 632, 0]
#       L polynomial:  [1, 0, -651, 0, -835233, 0, 2111932187]
# _______________________________________
#              prime:  1289
# L polynomial mod p:  [1, 0, 496, 0]
#       L polynomial:  [1, 0, 1785, 0, 2300865, 0, 2141700569]
# _______________________________________
#              prime:  1291
# L polynomial mod p:  [1, -36, 571, -55]
#       L polynomial:  [1, -36, -720, 72241, -929520, -60000516, 2151685171]
# _______________________________________
#              prime:  1297
# L polynomial mod p:  [1, 17, 300, -549]
#       L polynomial:  [1, 17, 300, -49835, 389100, 28597553, 2181825073]
# _______________________________________
#              prime:  1301
# L polynomial mod p:  [1, 0, 598, 0]
#       L polynomial:  [1, 0, 1899, 0, 2470599, 0, 2202073901]
# _______________________________________
#              prime:  1303
# L polynomial mod p:  [1, 39, -39, -522]
#       L polynomial:  [1, 39, -39, -10946, -50817, 66214551, 2212245127]
# _______________________________________
#              prime:  1307
# L polynomial mod p:  [1, 0, 178, 0]
#       L polynomial:  [1, 0, 1485, 0, 1940895, 0, 2232681443]
# _______________________________________
#              prime:  1319
# L polynomial mod p:  [1, 0, -651, 0]
#       L polynomial:  [1, 0, -651, 0, -858669, 0, 2294744759]
# _______________________________________
#              prime:  1321
# L polynomial mod p:  [1, -25, -335, 483]
#       L polynomial:  [1, -25, 986, -99913, 1302506, -43626025, 2305199161]
# _______________________________________
#              prime:  1327
# L polynomial mod p:  [1, -64, 230, -313]
#       L polynomial:  [1, -64, 1557, -33488, 2066139, -112699456, 2336752783]
# _______________________________________
#              prime:  1361
# L polynomial mod p:  [1, 0, 308, 0]
#       L polynomial:  [1, 0, 3030, 0, 4123830, 0, 2521008881]
# _______________________________________
#              prime:  1367
# L polynomial mod p:  [1, 0, -2, 0]
#       L polynomial:  [1, 0, -2, 0, -2734, 0, 2554497863]
# _______________________________________
#              prime:  1373
# L polynomial mod p:  [1, 0, -294, 0]
#       L polynomial:  [1, 0, -294, 0, -403662, 0, 2588282117]
# _______________________________________
#              prime:  1381
# L polynomial mod p:  [1, -41, 23, -369]
#       L polynomial:  [1, -41, 23, 25870, 31763, -78193601, 2633789341]
# _______________________________________
#              prime:  1399
# L polynomial mod p:  [1, 15, -195, -378]
#       L polynomial:  [1, 15, -195, 5218, -272805, 29358015, 2738124199]
# _______________________________________
#              prime:  1409
# L polynomial mod p:  [1, 0, -40, 0]
#       L polynomial:  [1, 0, 1369, 0, 1928921, 0, 2797260929]
# _______________________________________
#              prime:  1423
# L polynomial mod p:  [1, -36, 180, 670]
#       L polynomial:  [1, -36, 180, 60436, 256140, -72897444, 2881473967]
# _______________________________________
#              prime:  1427
# L polynomial mod p:  [1, 0, 302, 0]
#       L polynomial:  [1, 0, 3156, 0, 4503612, 0, 2905841483]
# _______________________________________
#              prime:  1429
# L polynomial mod p:  [1, -58, -399, 278]
#       L polynomial:  [1, -58, 2459, -59740, 3513911, -118438378, 2918076589]
# _______________________________________
#              prime:  1433
# L polynomial mod p:  [1, 0, 475, 0]
#       L polynomial:  [1, 0, 475, 0, 680675, 0, 2942649737]
# _______________________________________
#              prime:  1439
# L polynomial mod p:  [1, 0, -99, 0]
#       L polynomial:  [1, 0, 2779, 0, 3998981, 0, 2979767519]
# _______________________________________
#              prime:  1447
# L polynomial mod p:  [1, 85, 495, 300]
#       L polynomial:  [1, 85, 3389, 118954, 4903883, 177973765, 3029741623]
# _______________________________________
#              prime:  1451
# L polynomial mod p:  [1, 0, 526, 0]
#       L polynomial:  [1, 0, 1977, 0, 2868627, 0, 3054936851]
# _______________________________________
#              prime:  1453
# L polynomial mod p:  [1, -14, 202, -93]
#       L polynomial:  [1, -14, 1655, -16076, 2404715, -29556926, 3067586677]
# _______________________________________
#              prime:  1459
# L polynomial mod p:  [1, -12, 607, -496]
#       L polynomial:  [1, -12, -852, 81208, -1243068, -25544172, 3105745579]
# _______________________________________
#              prime:  1471
# L polynomial mod p:  [1, -63, 49, 107]
#       L polynomial:  [1, -63, -1422, 188395, -2091762, -136321983, 3183010111]
# _______________________________________
#              prime:  1481
# L polynomial mod p:  [1, 0, 525, 0]
#       L polynomial:  [1, 0, 3487, 0, 5164247, 0, 3248367641]
# _______________________________________
#              prime:  1483
# L polynomial mod p:  [1, -59, 299, -411]
#       L polynomial:  [1, -59, 4748, -172439, 7041284, -129758051, 3261545587]
# _______________________________________
#              prime:  1487
# L polynomial mod p:  [1, 0, -323, 0]
#       L polynomial:  [1, 0, -323, 0, -480301, 0, 3288008303]
# _______________________________________
#              prime:  1489
# L polynomial mod p:  [1, 7, 287, -618]
#       L polynomial:  [1, 7, 287, 112546, 427343, 15519847, 3301293169]
# _______________________________________
#              prime:  1493
# L polynomial mod p:  [1, 0, -651, 0]
#       L polynomial:  [1, 0, 2335, 0, 3486155, 0, 3327970157]
# _______________________________________
#              prime:  1499
# L polynomial mod p:  [1, 0, -246, 0]
#       L polynomial:  [1, 0, -246, 0, -368754, 0, 3368254499]
# _______________________________________
#              prime:  1511
# L polynomial mod p:  [1, 0, 231, 0]
#       L polynomial:  [1, 0, 3253, 0, 4915283, 0, 3449795831]
# _______________________________________
#              prime:  1523
# L polynomial mod p:  [1, 0, -27, 0]
#       L polynomial:  [1, 0, -27, 0, -41121, 0, 3532642667]
# _______________________________________
#              prime:  1531
# L polynomial mod p:  [1, 4, 63, 701]
#       L polynomial:  [1, 4, -1468, -10016, -2247508, 9375844, 3588604291]
# _______________________________________
#              prime:  1543
# L polynomial mod p:  [1, -66, 544, 272]
#       L polynomial:  [1, -66, 3630, -167915, 5601090, -157136034, 3673650007]
# _______________________________________
#              prime:  1549
# L polynomial mod p:  [1, 5, -513, -539]
#       L polynomial:  [1, 5, -513, 13402, -794637, 11997005, 3716672149]
# _______________________________________
#              prime:  1553
# L polynomial mod p:  [1, 0, -603, 0]
#       L polynomial:  [1, 0, 2503, 0, 3887159, 0, 3745539377]
# _______________________________________
#              prime:  1559
# L polynomial mod p:  [1, 0, 269, 0]
#       L polynomial:  [1, 0, -1290, 0, -2011110, 0, 3789119879]
# _______________________________________
#              prime:  1567
# L polynomial mod p:  [1, -54, 590, 16]
#       L polynomial:  [1, -54, 2157, -112808, 3380019, -132596406, 3847751263]
# _______________________________________
#              prime:  1571
# L polynomial mod p:  [1, 0, 5, 0]
#       L polynomial:  [1, 0, 1576, 0, 2475896, 0, 3877292411]
# _______________________________________
#              prime:  1579
# L polynomial mod p:  [1, 1, -703, -66]
#       L polynomial:  [1, 1, -703, 63094, -1110037, 2493241, 3936827539]
# _______________________________________
#              prime:  1583
# L polynomial mod p:  [1, 0, 107, 0]
#       L polynomial:  [1, 0, -1476, 0, -2336508, 0, 3966822287]
# _______________________________________
#              prime:  1597
# L polynomial mod p:  [1, 16, -136, -402]
#       L polynomial:  [1, 16, -136, -108998, -217192, 40806544, 4073003173]
# _______________________________________
#              prime:  1601
# L polynomial mod p:  [1, 0, -473, 0]
#       L polynomial:  [1, 0, 1128, 0, 1805928, 0, 4103684801]
# _______________________________________
#              prime:  1607
# L polynomial mod p:  [1, 0, 347, 0]
#       L polynomial:  [1, 0, 3561, 0, 5722527, 0, 4149995543]
# _______________________________________
#              prime:  1609
# L polynomial mod p:  [1, -1, -270, -757]
#       L polynomial:  [1, -1, -270, 50731, -434430, -2588881, 4165509529]
# _______________________________________
#              prime:  1613
# L polynomial mod p:  [1, 0, 492, 0]
#       L polynomial:  [1, 0, 3718, 0, 5997134, 0, 4196653397]
# _______________________________________
#              prime:  1619
# L polynomial mod p:  [1, 0, 47, 0]
#       L polynomial:  [1, 0, -1572, 0, -2545068, 0, 4243659659]
# _______________________________________
#              prime:  1621
# L polynomial mod p:  [1, -64, -181, -564]
#       L polynomial:  [1, -64, 1440, -3806, 2334240, -168169024, 4259406061]
# _______________________________________
#              prime:  1627
# L polynomial mod p:  [1, -5, -94, -781]
#       L polynomial:  [1, -5, -94, 109855, -152938, -13235645, 4306878883]
# _______________________________________
#              prime:  1637
# L polynomial mod p:  [1, 0, 67, 0]
#       L polynomial:  [1, 0, 1704, 0, 2789448, 0, 4386781853]
# _______________________________________
#              prime:  1657
# L polynomial mod p:  [1, -94, 684, 31]
#       L polynomial:  [1, -94, 5655, -283316, 9370335, -258091006, 4549540393]
# _______________________________________
#              prime:  1663
# L polynomial mod p:  [1, 12, 467, 665]
#       L polynomial:  [1, 12, 2130, 13969, 3542190, 33186828, 4599141247]
# _______________________________________
#              prime:  1667
# L polynomial mod p:  [1, 0, 747, 0]
#       L polynomial:  [1, 0, 747, 0, 1245249, 0, 4632407963]
# _______________________________________
#              prime:  1669
# L polynomial mod p:  [1, -34, 817, 114]
#       L polynomial:  [1, -34, -852, 46846, -1421988, -94709074, 4649101309]
# _______________________________________
#              prime:  1693
# L polynomial mod p:  [1, 49, 565, 115]
#       L polynomial:  [1, 49, 2258, 111853, 3822794, 140446201, 4852559557]
# _______________________________________
#              prime:  1697
# L polynomial mod p:  [1, 0, -335, 0]
#       L polynomial:  [1, 0, 1362, 0, 2311314, 0, 4887035873]
# _______________________________________
#              prime:  1699
# L polynomial mod p:  [1, -71, -289, 842]
#       L polynomial:  [1, -71, 4808, -235319, 8168792, -204948671, 4904335099]
# _______________________________________
#              prime:  1709
# L polynomial mod p:  [1, 0, 807, 0]
#       L polynomial:  [1, 0, 4225, 0, 7220525, 0, 4991443829]
# _______________________________________
#              prime:  1721
# L polynomial mod p:  [1, 0, -695, 0]
#       L polynomial:  [1, 0, 1026, 0, 1765746, 0, 5097328361]
# _______________________________________
#              prime:  1723
# L polynomial mod p:  [1, -46, -660, -404]
#       L polynomial:  [1, -46, -660, 128821, -1137180, -136561534, 5115120067]
# _______________________________________
#              prime:  1733
# L polynomial mod p:  [1, 0, -741, 0]
#       L polynomial:  [1, 0, -741, 0, -1284153, 0, 5204699837]
# _______________________________________
#              prime:  1741
# L polynomial mod p:  [1, -55, 78, 655]
#       L polynomial:  [1, -55, 3560, -96841, 6197960, -166709455, 5277112021]
# _______________________________________
#              prime:  1747
# L polynomial mod p:  [1, 30, 654, -287]
#       L polynomial:  [1, 30, 654, 41641, 1142538, 91560270, 5331859723]
# _______________________________________
#              prime:  1753
# L polynomial mod p:  [1, -16, 196, -381]
#       L polynomial:  [1, -16, -1557, 43444, -2729421, -49168144, 5386984777]
# _______________________________________
#              prime:  1759
# L polynomial mod p:  [1, -32, 437, 519]
#       L polynomial:  [1, -32, 437, -71600, 768683, -99010592, 5442488479]
# _______________________________________
#              prime:  1777
# L polynomial mod p:  [1, -9, 193, 88]
#       L polynomial:  [1, -9, -1584, 16081, -2814768, -28419561, 5611284433]
# _______________________________________
#              prime:  1783
# L polynomial mod p:  [1, -22, 516, 254]
#       L polynomial:  [1, -22, -1267, 53744, -2259061, -69939958, 5668315687]
# _______________________________________
#              prime:  1787
# L polynomial mod p:  [1, 0, 177, 0]
#       L polynomial:  [1, 0, 177, 0, 316299, 0, 5706550403]
# _______________________________________
#              prime:  1789
# L polynomial mod p:  [1, -81, 469, -398]
#       L polynomial:  [1, -81, -1320, 251851, -2361480, -259242201, 5725732069]
# _______________________________________
#              prime:  1801
# L polynomial mod p:  [1, -16, 109, -294]
#       L polynomial:  [1, -16, -1692, 66343, -3047292, -51897616, 5841725401]
# _______________________________________
#              prime:  1811
# L polynomial mod p:  [1, 0, 362, 0]
#       L polynomial:  [1, 0, 3984, 0, 7215024, 0, 5939574731]
# _______________________________________
#              prime:  1823
# L polynomial mod p:  [1, 0, 621, 0]
#       L polynomial:  [1, 0, 621, 0, 1132083, 0, 6058428767]
# _______________________________________
#              prime:  1831
# L polynomial mod p:  [1, 87, -482, 402]
#       L polynomial:  [1, 87, 3180, 79135, 5822580, 291672807, 6138539191]
# _______________________________________
#              prime:  1847
# L polynomial mod p:  [1, 0, -850, 0]
#       L polynomial:  [1, 0, 2844, 0, 5252868, 0, 6300872423]
# _______________________________________
#              prime:  1861
# L polynomial mod p:  [1, -176, -240, -22]
#       L polynomial:  [1, -176, 14648, -766754, 27259928, -609544496, 6445240381]
# _______________________________________
#              prime:  1867
# L polynomial mod p:  [1, -5, -657, 336]
#       L polynomial:  [1, -5, 3077, 19006, 5744759, -17428445, 6507781363]
# _______________________________________
#              prime:  1871
# L polynomial mod p:  [1, 0, 482, 0]
#       L polynomial:  [1, 0, 2353, 0, 4402463, 0, 6549699311]
# _______________________________________
#              prime:  1873
# L polynomial mod p:  [1, 56, 483, 670]
#       L polynomial:  [1, 56, 483, -77996, 904659, 196455224, 6570725617]
# _______________________________________
#              prime:  1877
# L polynomial mod p:  [1, 0, -337, 0]
#       L polynomial:  [1, 0, 3417, 0, 6413709, 0, 6612913133]
# _______________________________________
#              prime:  1879
# L polynomial mod p:  [1, 2, -282, 523]
#       L polynomial:  [1, 2, -282, 90715, -529878, 7061282, 6634074439]
# _______________________________________
#              prime:  1889
# L polynomial mod p:  [1, 0, 9, 0]
#       L polynomial:  [1, 0, 9, 0, 17001, 0, 6740558369]
# _______________________________________
#              prime:  1901
# L polynomial mod p:  [1, 0, -907, 0]
#       L polynomial:  [1, 0, 994, 0, 1889594, 0, 6869835701]
# _______________________________________
#              prime:  1907
# L polynomial mod p:  [1, 0, 429, 0]
#       L polynomial:  [1, 0, 429, 0, 818103, 0, 6935089643]
# _______________________________________
#              prime:  1913
# L polynomial mod p:  [1, 0, -944, 0]
#       L polynomial:  [1, 0, 969, 0, 1853697, 0, 7000755497]
# _______________________________________
#              prime:  1931
# L polynomial mod p:  [1, 0, 246, 0]
#       L polynomial:  [1, 0, 246, 0, 475026, 0, 7200237491]
# _______________________________________
#              prime:  1933
# L polynomial mod p:  [1, -32, 228, -393]
#       L polynomial:  [1, -32, -1705, 140716, -3295765, -119567648, 7222633237]
# _______________________________________
#              prime:  1949
# L polynomial mod p:  [1, 0, 526, 0]
#       L polynomial:  [1, 0, 2475, 0, 4823775, 0, 7403473349]
# _______________________________________
#              prime:  1951
# L polynomial mod p:  [1, -5, 608, 436]
#       L polynomial:  [1, -5, 608, -145889, 1186208, -19032005, 7426288351]
# _______________________________________
#              prime:  1973
# L polynomial mod p:  [1, 0, 848, 0]
#       L polynomial:  [1, 0, 2821, 0, 5565833, 0, 7680354317]
# _______________________________________
#              prime:  1979
# L polynomial mod p:  [1, 0, -828, 0]
#       L polynomial:  [1, 0, 5109, 0, 10110711, 0, 7750636739]
# _______________________________________
#              prime:  1987
# L polynomial mod p:  [1, -49, 0, -664]
#       L polynomial:  [1, -49, 0, 80803, 0, -193460281, 7845011803]
# _______________________________________
#              prime:  1993
# L polynomial mod p:  [1, 116, -445, -136]
#       L polynomial:  [1, 116, 5534, 209129, 11029262, 460757684, 7916293657]
# _______________________________________
#              prime:  1997
# L polynomial mod p:  [1, 0, -650, 0]
#       L polynomial:  [1, 0, 1347, 0, 2689959, 0, 7964053973]
# _______________________________________
#              prime:  1999
# L polynomial mod p:  [1, -33, -739, -6]
#       L polynomial:  [1, -33, 1260, -105953, 2518740, -131868033, 7988005999]
# _______________________________________
#              prime:  2003
# L polynomial mod p:  [1, 0, -241, 0]
#       L polynomial:  [1, 0, 3765, 0, 7541295, 0, 8036054027]
# _______________________________________
#              prime:  2011
# L polynomial mod p:  [1, -67, -678, 382]
#       L polynomial:  [1, -67, -678, 151207, -1363458, -270956107, 8132727331]
# _______________________________________
#              prime:  2017
# L polynomial mod p:  [1, 159, 870, -678]
#       L polynomial:  [1, 159, 12972, 691153, 26164524, 646857951, 8205738913]
# _______________________________________
#              prime:  2027
# L polynomial mod p:  [1, 0, -340, 0]
#       L polynomial:  [1, 0, 1687, 0, 3419549, 0, 8328393683]
# _______________________________________
#              prime:  2029
# L polynomial mod p:  [1, -25, 540, 670]
#       L polynomial:  [1, -25, 540, -5417, 1095660, -102921025, 8353070389]
# _______________________________________
#              prime:  2039
# L polynomial mod p:  [1, 0, -841, 0]
#       L polynomial:  [1, 0, 1198, 0, 2442722, 0, 8477185319]
# _______________________________________
#              prime:  2053
# L polynomial mod p:  [1, -53, -568, -462]
#       L polynomial:  [1, -53, 5591, -213974, 11478323, -223384877, 8653002877]
# _______________________________________
#              prime:  2063
# L polynomial mod p:  [1, 0, -228, 0]
#       L polynomial:  [1, 0, 3898, 0, 8041574, 0, 8780064047]
# _______________________________________
#              prime:  2069
# L polynomial mod p:  [1, 0, -128, 0]
#       L polynomial:  [1, 0, -128, 0, -264832, 0, 8856894509]
# _______________________________________
#              prime:  2081
# L polynomial mod p:  [1, 0, 313, 0]
#       L polynomial:  [1, 0, 2394, 0, 4981914, 0, 9011897441]
# _______________________________________
#              prime:  2083
# L polynomial mod p:  [1, -94, -15, 136]
#       L polynomial:  [1, -94, 6234, -268571, 12985422, -407855566, 9037905787]
# _______________________________________
#              prime:  2087
# L polynomial mod p:  [1, 0, -236, 0]
#       L polynomial:  [1, 0, 1851, 0, 3863037, 0, 9090072503]
# _______________________________________
#              prime:  2089
# L polynomial mod p:  [1, -34, -499, -265]
#       L polynomial:  [1, -34, 1590, 22714, 3321510, -148373314, 9116230969]
# _______________________________________
#              prime:  2099
# L polynomial mod p:  [1, 0, 652, 0]
#       L polynomial:  [1, 0, 652, 0, 1368548, 0, 9247776299]
# _______________________________________
#              prime:  2111
# L polynomial mod p:  [1, 0, -680, 0]
#       L polynomial:  [1, 0, 1431, 0, 3020841, 0, 9407293631]
# _______________________________________
#              prime:  2113
# L polynomial mod p:  [1, 32, 563, 1012]
#       L polynomial:  [1, 32, 2676, 70741, 5654388, 142872608, 9434056897]
# _______________________________________
#              prime:  2129
# L polynomial mod p:  [1, 0, -427, 0]
#       L polynomial:  [1, 0, 3831, 0, 8156199, 0, 9649992689]
# _______________________________________
#              prime:  2131
# L polynomial mod p:  [1, -54, -553, 299]
#       L polynomial:  [1, -54, 1578, -78548, 3362718, -245222694, 9677214091]
# _______________________________________
#              prime:  2137
# L polynomial mod p:  [1, -40, -547, -729]
#       L polynomial:  [1, -40, 5864, -156730, 12531368, -182670760, 9759185353]
# _______________________________________
#              prime:  2141
# L polynomial mod p:  [1, 0, -858, 0]
#       L polynomial:  [1, 0, 5565, 0, 11914665, 0, 9814089221]
# _______________________________________
#              prime:  2143
# L polynomial mod p:  [1, 9, 720, -792]
#       L polynomial:  [1, 9, 720, -62939, 1542960, 41332041, 9841618207]
# _______________________________________
#              prime:  2153
# L polynomial mod p:  [1, 0, 426, 0]
#       L polynomial:  [1, 0, 426, 0, 917178, 0, 9980035577]
# _______________________________________
#              prime:  2161
# L polynomial mod p:  [1, 81, -716, 377]
#       L polynomial:  [1, 81, 3606, 95461, 7792566, 378263601, 10091699281]
# _______________________________________
#              prime:  2179
# L polynomial mod p:  [1, 96, -504, -1088]
#       L polynomial:  [1, 96, -504, -262568, -1098216, 455811936, 10345981339]
# _______________________________________
#              prime:  2203
# L polynomial mod p:  [1, 14, -852, 236]
#       L polynomial:  [1, 14, -852, -134147, -1876956, 67944926, 10691619427]
# _______________________________________
#              prime:  2207
# L polynomial mod p:  [1, 0, -196, 0]
#       L polynomial:  [1, 0, 4218, 0, 9309126, 0, 10749963743]
# _______________________________________
#              prime:  2213
# L polynomial mod p:  [1, 0, 125, 0]
#       L polynomial:  [1, 0, 4551, 0, 10071363, 0, 10837877597]
# _______________________________________
#              prime:  2221
# L polynomial mod p:  [1, 53, -1045, 492]
#       L polynomial:  [1, 53, 1176, -10613, 2611896, 261440573, 10955839861]
# _______________________________________
#              prime:  2237
# L polynomial mod p:  [1, 0, -31, 0]
#       L polynomial:  [1, 0, 4443, 0, 9938991, 0, 11194326053]
# _______________________________________
#              prime:  2239
# L polynomial mod p:  [1, 3, -111, -273]
#       L polynomial:  [1, 3, -111, -51770, -248529, 15039363, 11224377919]
# _______________________________________
#              prime:  2243
# L polynomial mod p:  [1, 0, 196, 0]
#       L polynomial:  [1, 0, 2439, 0, 5470677, 0, 11284642907]
# _______________________________________
#              prime:  2251
# L polynomial mod p:  [1, 65, -783, 810]
#       L polynomial:  [1, 65, -783, -206282, -1762533, 329355065, 11405819251]
# _______________________________________
#              prime:  2267
# L polynomial mod p:  [1, 0, 1097, 0]
#       L polynomial:  [1, 0, 5631, 0, 12765477, 0, 11650768163]
# _______________________________________
#              prime:  2269
# L polynomial mod p:  [1, 73, 542, -87]
#       L polynomial:  [1, 73, 542, -127151, 1229798, 375830353, 11681631109]
# _______________________________________
#              prime:  2273
# L polynomial mod p:  [1, 0, 111, 0]
#       L polynomial:  [1, 0, 111, 0, 252303, 0, 11743520417]
# _______________________________________
#              prime:  2281
# L polynomial mod p:  [1, 39, 771, 862]
#       L polynomial:  [1, 39, 771, 28234, 1758651, 202915479, 11867954041]
# _______________________________________
#              prime:  2287
# L polynomial mod p:  [1, -21, 1051, -619]
#       L polynomial:  [1, -21, -1236, 3955, -2826732, -109837749, 11961853903]
# _______________________________________
#              prime:  2293
# L polynomial mod p:  [1, 78, -1055, 433]
#       L polynomial:  [1, 78, 3531, 199924, 8096583, 410112222, 12056247757]
# _______________________________________
#              prime:  2297
# L polynomial mod p:  [1, 0, 846, 0]
#       L polynomial:  [1, 0, 5440, 0, 12495680, 0, 12119452073]
# _______________________________________
#              prime:  2309
# L polynomial mod p:  [1, 0, 188, 0]
#       L polynomial:  [1, 0, 4806, 0, 11097054, 0, 12310389629]
# _______________________________________
#              prime:  2311
# L polynomial mod p:  [1, -40, 607, -340]
#       L polynomial:  [1, -40, -1704, 233071, -3937944, -213628840, 12342406231]
# _______________________________________
#              prime:  2333
# L polynomial mod p:  [1, 0, -936, 0]
#       L polynomial:  [1, 0, -936, 0, -2183688, 0, 12698260037]
# _______________________________________
#              prime:  2339
# L polynomial mod p:  [1, 0, -238, 0]
#       L polynomial:  [1, 0, 4440, 0, 10385160, 0, 12796484219]
# _______________________________________
#              prime:  2341
# L polynomial mod p:  [1, -36, 71, -201]
#       L polynomial:  [1, -36, 2412, -11906, 5646492, -197290116, 12829337821]
# _______________________________________
#              prime:  2347
# L polynomial mod p:  [1, 47, 860, 640]
#       L polynomial:  [1, 47, 860, 59315, 2018420, 258895223, 12928235923]
# _______________________________________
#              prime:  2351
# L polynomial mod p:  [1, 0, 275, 0]
#       L polynomial:  [1, 0, 4977, 0, 11700927, 0, 12994449551]
# _______________________________________
#              prime:  2357
# L polynomial mod p:  [1, 0, 732, 0]
#       L polynomial:  [1, 0, -1625, 0, -3830125, 0, 13094193293]
# _______________________________________
#              prime:  2371
# L polynomial mod p:  [1, -9, 424, -367]
#       L polynomial:  [1, -9, 5166, -66755, 12248586, -50594769, 13328910811]
# _______________________________________
#              prime:  2377
# L polynomial mod p:  [1, 86, -295, -937]
#       L polynomial:  [1, 86, 2082, -31838, 4948914, 485911094, 13430356633]
# _______________________________________
#              prime:  2381
# L polynomial mod p:  [1, 0, -405, 0]
#       L polynomial:  [1, 0, -405, 0, -964305, 0, 13498272341]
# _______________________________________
#              prime:  2383
# L polynomial mod p:  [1, 23, -24, 791]
#       L polynomial:  [1, 23, -24, -151721, -57192, 130609847, 13532315887]
# _______________________________________
#              prime:  2389
# L polynomial mod p:  [1, -18, 1122, -352]
#       L polynomial:  [1, -18, 1122, 90430, 2680458, -102731778, 13634789869]
# _______________________________________
#              prime:  2393
# L polynomial mod p:  [1, 0, 836, 0]
#       L polynomial:  [1, 0, -1557, 0, -3725901, 0, 13703392457]
# _______________________________________
#              prime:  2399
# L polynomial mod p:  [1, 0, -360, 0]
#       L polynomial:  [1, 0, 6837, 0, 16401963, 0, 13806727199]
# _______________________________________
#              prime:  2411
# L polynomial mod p:  [1, 0, 494, 0]
#       L polynomial:  [1, 0, -1917, 0, -4621887, 0, 14014952531]
# _______________________________________
#              prime:  2417
# L polynomial mod p:  [1, 0, 984, 0]
#       L polynomial:  [1, 0, -1433, 0, -3463561, 0, 14119845713]
# _______________________________________
#              prime:  2423
# L polynomial mod p:  [1, 0, -727, 0]
#       L polynomial:  [1, 0, 1696, 0, 4109408, 0, 14225260967]
# _______________________________________
#              prime:  2437
# L polynomial mod p:  [1, -66, -828, 1065]
#       L polynomial:  [1, -66, -828, 237454, -2017836, -391971954, 14473267453]
# _______________________________________
#              prime:  2441
# L polynomial mod p:  [1, 0, -1188, 0]
#       L polynomial:  [1, 0, 6135, 0, 14975535, 0, 14544652121]
# _______________________________________
#              prime:  2447
# L polynomial mod p:  [1, 0, -255, 0]
#       L polynomial:  [1, 0, 4639, 0, 11351633, 0, 14652168623]
# _______________________________________
#              prime:  2459
# L polynomial mod p:  [1, 0, -686, 0]
#       L polynomial:  [1, 0, 1773, 0, 4359807, 0, 14868788579]
# _______________________________________
#              prime:  2467
# L polynomial mod p:  [1, 71, -198, 1103]
#       L polynomial:  [1, 71, -198, -141983, -488466, 432112319, 15014381563]
# _______________________________________
#              prime:  2473
# L polynomial mod p:  [1, -57, -1026, 523]
#       L polynomial:  [1, -57, -1026, 148903, -2537298, -348596553, 15124197817]
# _______________________________________
#              prime:  2477
# L polynomial mod p:  [1, 0, -919, 0]
#       L polynomial:  [1, 0, 4035, 0, 9994695, 0, 15197705333]
# _______________________________________
#              prime:  2503
# L polynomial mod p:  [1, -19, 1116, -112]
#       L polynomial:  [1, -19, -1387, 14906, -3471661, -119035171, 15681317527]
# _______________________________________
#              prime:  2521
# L polynomial mod p:  [1, -119, 1081, 748]
#       L polynomial:  [1, -119, 3602, -6815, 9080642, -756297479, 16022066761]
# _______________________________________
#              prime:  2531
# L polynomial mod p:  [1, 0, 427, 0]
#       L polynomial:  [1, 0, 2958, 0, 7486698, 0, 16213487291]
# _______________________________________
#              prime:  2539
# L polynomial mod p:  [1, 60, -456, 801]
#       L polynomial:  [1, 60, -456, -95681, -1157784, 386791260, 16367716819]
# _______________________________________
#              prime:  2543
# L polynomial mod p:  [1, 0, -149, 0]
#       L polynomial:  [1, 0, 7480, 0, 19021640, 0, 16445197007]
# _______________________________________
#              prime:  2549
# L polynomial mod p:  [1, 0, 245, 0]
#       L polynomial:  [1, 0, 5343, 0, 13619307, 0, 16561875149]
# _______________________________________
#              prime:  2551
# L polynomial mod p:  [1, -58, 523, 316]
#       L polynomial:  [1, -58, -2028, 337048, -5173428, -377440858, 16600890151]
# _______________________________________
#              prime:  2557
# L polynomial mod p:  [1, 23, 763, 1236]
#       L polynomial:  [1, 23, -1794, -164969, -4587258, 150379727, 16718302693]
# _______________________________________
#              prime:  2579
# L polynomial mod p:  [1, 0, 1022, 0]
#       L polynomial:  [1, 0, 6180, 0, 15938220, 0, 17153550539]
# _______________________________________
#              prime:  2591
# L polynomial mod p:  [1, 0, -513, 0]
#       L polynomial:  [1, 0, 4669, 0, 12097379, 0, 17394111071]
# _______________________________________
#              prime:  2593
# L polynomial mod p:  [1, 97, -935, -799]
#       L polynomial:  [1, 97, 1658, -104519, 4299194, 652193953, 17434421857]
# _______________________________________
#              prime:  2609
# L polynomial mod p:  [1, 0, 1074, 0]
#       L polynomial:  [1, 0, 1074, 0, 2802066, 0, 17759152529]
# _______________________________________
#              prime:  2617
# L polynomial mod p:  [1, 116, -39, -546]
#       L polynomial:  [1, 116, 7812, 394621, 20444004, 794447924, 17923019113]
# _______________________________________
#              prime:  2621
# L polynomial mod p:  [1, 0, 267, 0]
#       L polynomial:  [1, 0, 267, 0, 699807, 0, 18005329061]
# _______________________________________
#              prime:  2633
# L polynomial mod p:  [1, 0, 500, 0]
#       L polynomial:  [1, 0, 3133, 0, 8249189, 0, 18253770137]
# _______________________________________
#              prime:  2647
# L polynomial mod p:  [1, -107, 125, -62]
#       L polynomial:  [1, -107, 8066, -500345, 21350702, -749707163, 18546494023]
# _______________________________________
#              prime:  2657
# L polynomial mod p:  [1, 0, 1143, 0]
#       L polynomial:  [1, 0, 1143, 0, 3036951, 0, 18757487393]
# _______________________________________
#              prime:  2659
# L polynomial mod p:  [1, -26, 1241, -1133]
#       L polynomial:  [1, -26, 1241, 102568, 3299819, -183827306, 18799877179]
# _______________________________________
#              prime:  2663
# L polynomial mod p:  [1, 0, 665, 0]
#       L polynomial:  [1, 0, 5991, 0, 15954033, 0, 18884848247]
# _______________________________________
#              prime:  2671
# L polynomial mod p:  [1, 19, -895, 1323]
#       L polynomial:  [1, 19, -895, -284474, -2390545, 135550579, 19055557711]
# _______________________________________
#              prime:  2677
# L polynomial mod p:  [1, 3, -201, 1021]
#       L polynomial:  [1, 3, -201, -231878, -538077, 21498987, 19184262733]
# _______________________________________
#              prime:  2683
# L polynomial mod p:  [1, 203, -758, 1200]
#       L polynomial:  [1, 203, 20706, 1323919, 55554198, 1461293267, 19313545987]
# _______________________________________
#              prime:  2687
# L polynomial mod p:  [1, 0, 154, 0]
#       L polynomial:  [1, 0, 2841, 0, 7633767, 0, 19400056703]
# _______________________________________
#              prime:  2689
# L polynomial mod p:  [1, -50, -718, 1298]
#       L polynomial:  [1, -50, -718, 151882, -1930702, -361536050, 19443408769]
# _______________________________________
#              prime:  2693
# L polynomial mod p:  [1, 0, 815, 0]
#       L polynomial:  [1, 0, -1878, 0, -5057454, 0, 19530306557]
# _______________________________________
#              prime:  2699
# L polynomial mod p:  [1, 0, 758, 0]
#       L polynomial:  [1, 0, -1941, 0, -5238759, 0, 19661138099]
# _______________________________________
#              prime:  2707
# L polynomial mod p:  [1, 85, 900, -249]
#       L polynomial:  [1, 85, 6314, 465355, 17091998, 622867165, 19836487243]
# _______________________________________
#              prime:  2711
# L polynomial mod p:  [1, 0, 143, 0]
#       L polynomial:  [1, 0, -2568, 0, -6961848, 0, 19924551431]
# _______________________________________
#              prime:  2713
# L polynomial mod p:  [1, 71, 1024, -1265]
#       L polynomial:  [1, 71, -1689, -318686, -4582257, 522586199, 19968681097]
# _______________________________________
#              prime:  2719
# L polynomial mod p:  [1, -49, -843, 879]
#       L polynomial:  [1, -49, -843, 166738, -2292117, -362255089, 20101460959]
# _______________________________________
#              prime:  2729
# L polynomial mod p:  [1, 0, 1360, 0]
#       L polynomial:  [1, 0, 4089, 0, 11158881, 0, 20324066489]
# _______________________________________
#              prime:  2731
# L polynomial mod p:  [1, 3, 1206, 13]
#       L polynomial:  [1, 3, 1206, -98303, 3293586, 22375083, 20368783891]
# _______________________________________
#              prime:  2741
# L polynomial mod p:  [1, 0, 372, 0]
#       L polynomial:  [1, 0, -2369, 0, -6493429, 0, 20593355021]
# _______________________________________
#              prime:  2749
# L polynomial mod p:  [1, -16, -940, 470]
#       L polynomial:  [1, -16, -940, 272621, -2584060, -120912016, 20774195749]
# _______________________________________
#              prime:  2753
# L polynomial mod p:  [1, 0, -1206, 0]
#       L polynomial:  [1, 0, 7053, 0, 19416909, 0, 20865011777]
# _______________________________________
#              prime:  2767
# L polynomial mod p:  [1, 2, 189, 488]
#       L polynomial:  [1, 2, -2578, 488, -7133326, 15312578, 21184951663]
# _______________________________________
#              prime:  2777
# L polynomial mod p:  [1, 0, -151, 0]
#       L polynomial:  [1, 0, 2626, 0, 7292402, 0, 21415471433]
# _______________________________________
#              prime:  2789
# L polynomial mod p:  [1, 0, -1350, 0]
#       L polynomial:  [1, 0, 4228, 0, 11791892, 0, 21694295069]
# _______________________________________
#              prime:  2791
# L polynomial mod p:  [1, 96, 460, 981]
#       L polynomial:  [1, 96, 6042, 347065, 16863222, 747809376, 21740999671]
# _______________________________________
#              prime:  2797
# L polynomial mod p:  [1, -36, 744, 749]
#       L polynomial:  [1, -36, 744, -119522, 2080968, -281635524, 21881515573]
# _______________________________________
#              prime:  2801
# L polynomial mod p:  [1, 0, -487, 0]
#       L polynomial:  [1, 0, 5115, 0, 14327115, 0, 21975528401]
# _______________________________________
#              prime:  2803
# L polynomial mod p:  [1, 185, -623, 959]
#       L polynomial:  [1, 185, 18998, 1228673, 53251394, 1453509665, 22022635627]
# _______________________________________
#              prime:  2819
# L polynomial mod p:  [1, 0, 285, 0]
#       L polynomial:  [1, 0, 285, 0, 803415, 0, 22401919259]
# _______________________________________
#              prime:  2833
# L polynomial mod p:  [1, -27, 958, 1163]
#       L polynomial:  [1, -27, 6624, -112157, 18765792, -216699003, 22737343537]
# _______________________________________
#              prime:  2837
# L polynomial mod p:  [1, 0, 1112, 0]
#       L polynomial:  [1, 0, -1725, 0, -4893825, 0, 22833790253]
# _______________________________________
#              prime:  2843
# L polynomial mod p:  [1, 0, -146, 0]
#       L polynomial:  [1, 0, 2697, 0, 7667571, 0, 22978971107]
# _______________________________________
#              prime:  2851
# L polynomial mod p:  [1, -72, -1202, 382]
#       L polynomial:  [1, -72, 4500, -119360, 12829500, -585230472, 23173501051]
# _______________________________________
#              prime:  2857
# L polynomial mod p:  [1, 83, 359, -262]
#       L polynomial:  [1, 83, 3216, 116875, 9188112, 677483267, 23320116793]
# _______________________________________
#              prime:  2861
# L polynomial mod p:  [1, 0, -305, 0]
#       L polynomial:  [1, 0, -305, 0, -872605, 0, 23418203381]
# _______________________________________
#              prime:  2879
# L polynomial mod p:  [1, 0, -39, 0]
#       L polynomial:  [1, 0, 5719, 0, 16465001, 0, 23862997439]
# _______________________________________
#              prime:  2887
# L polynomial mod p:  [1, -77, 266, -186]
#       L polynomial:  [1, -77, 266, 210565, 767942, -641777213, 24062478103]
# _______________________________________
#              prime:  2897
# L polynomial mod p:  [1, 0, -63, 0]
#       L polynomial:  [1, 0, -63, 0, -182511, 0, 24313388273]
# _______________________________________
#              prime:  2903
# L polynomial mod p:  [1, 0, 1259, 0]
#       L polynomial:  [1, 0, -1644, 0, -4772532, 0, 24464768327]
# _______________________________________
#              prime:  2909
# L polynomial mod p:  [1, 0, -1404, 0]
#       L polynomial:  [1, 0, 7323, 0, 21302607, 0, 24616775429]
# _______________________________________
#              prime:  2917
# L polynomial mod p:  [1, -81, 427, -268]
#       L polynomial:  [1, -81, -2490, 451867, -7263330, -689220009, 24820429213]
# _______________________________________
#              prime:  2927
# L polynomial mod p:  [1, 0, -1182, 0]
#       L polynomial:  [1, 0, 4672, 0, 13674944, 0, 25076571983]
# _______________________________________
#              prime:  2939
# L polynomial mod p:  [1, 0, -7, 0]
#       L polynomial:  [1, 0, 5871, 0, 17254869, 0, 25386262019]
# _______________________________________
#              prime:  2953
# L polynomial mod p:  [1, 79, 27, 999]
#       L polynomial:  [1, 79, -2926, -465575, -8640478, 688896511, 25750777177]
# _______________________________________
#              prime:  2957
# L polynomial mod p:  [1, 0, 681, 0]
#       L polynomial:  [1, 0, 681, 0, 2013717, 0, 25855561493]
# _______________________________________
#              prime:  2963
# L polynomial mod p:  [1, 0, -900, 0]
#       L polynomial:  [1, 0, -900, 0, -2666700, 0, 26013270347]
# _______________________________________
#              prime:  2969
# L polynomial mod p:  [1, 0, 987, 0]
#       L polynomial:  [1, 0, 987, 0, 2930403, 0, 26171619209]
# _______________________________________
#              prime:  2971
# L polynomial mod p:  [1, 79, 813, -767]
#       L polynomial:  [1, 79, -2158, -428591, -6411418, 697320439, 26224544611]
# _______________________________________
#              prime:  2999
# L polynomial mod p:  [1, 0, 801, 0]
#       L polynomial:  [1, 0, 6799, 0, 20390201, 0, 26973008999]
# _______________________________________
#              prime:  3001
# L polynomial mod p:  [1, -38, 49, -985]
#       L polynomial:  [1, -38, 3050, -112022, 9153050, -342228038, 27027009001]
# _______________________________________
#              prime:  3011
# L polynomial mod p:  [1, 0, -289, 0]
#       L polynomial:  [1, 0, 5733, 0, 17262063, 0, 27298090331]
# _______________________________________
#              prime:  3019
# L polynomial mod p:  [1, -46, -419, -1325]
#       L polynomial:  [1, -46, 2600, -152275, 7849400, -419260606, 27516255859]
# _______________________________________
#              prime:  3023
# L polynomial mod p:  [1, 0, 1033, 0]
#       L polynomial:  [1, 0, 4056, 0, 12261288, 0, 27625773167]
# _______________________________________
#              prime:  3037
# L polynomial mod p:  [1, 84, -547, 774]
#       L polynomial:  [1, 84, 2490, 12922, 7562130, 774762996, 28011371653]
# _______________________________________
#              prime:  3041
# L polynomial mod p:  [1, 0, -92, 0]
#       L polynomial:  [1, 0, 2949, 0, 8967909, 0, 28122197921]
# _______________________________________
#              prime:  3049
# L polynomial mod p:  [1, -34, -130, -740]
#       L polynomial:  [1, -34, 2919, 72436, 8900031, -316077634, 28344726649]
# _______________________________________
#              prime:  3061
# L polynomial mod p:  [1, -58, -1159, 390]
#       L polynomial:  [1, -58, 1902, 86098, 5822022, -543443818, 28680715981]
# _______________________________________
#              prime:  3067
# L polynomial mod p:  [1, -23, 1308, -1105]
#       L polynomial:  [1, -23, -1759, 14230, -5394853, -216349247, 28849701763]
# _______________________________________
#              prime:  3079
# L polynomial mod p:  [1, 1, 170, 1200]
#       L polynomial:  [1, 1, 170, 262915, 523430, 9480241, 29189662039]
# _______________________________________
#              prime:  3083
# L polynomial mod p:  [1, 0, 849, 0]
#       L polynomial:  [1, 0, 849, 0, 2617467, 0, 29303572787]
# _______________________________________
#              prime:  3089
# L polynomial mod p:  [1, 0, -1210, 0]
#       L polynomial:  [1, 0, 4968, 0, 15346152, 0, 29474993969]
# _______________________________________
#              prime:  3109
# L polynomial mod p:  [1, 78, -671, -1174]
#       L polynomial:  [1, 78, 5547, 303508, 17245623, 753938718, 30051224029]
# _______________________________________
#              prime:  3119
# L polynomial mod p:  [1, 0, -1365, 0]
#       L polynomial:  [1, 0, 7992, 0, 24927048, 0, 30342134159]
# _______________________________________
#              prime:  3121
# ...
# _______________________________________
#              prime:  3271
# L polynomial mod p:  [1, -32, -820, 130]
#       L polynomial:  [1, -32, -820, 333772, -2682220, -342382112, 34997871511]
# _______________________________________
#              prime:  3299
# L polynomial mod p:  [1, 0, 731, 0]
#       L polynomial:  [1, 0, 7329, 0, 24178371, 0, 35904339899]
# _______________________________________
#              prime:  3301
# L polynomial mod p:  [1, 63, 349, 1267]
#       L polynomial:  [1, 63, -2952, -434465, -9744552, 686485863, 35969679901]
# _______________________________________
#              prime:  3307
# L polynomial mod p:  [1, -8, 1548, -813]
#       L polynomial:  [1, -8, -1759, 181072, -5817013, -87489992, 36166175443]
# _______________________________________
#              prime:  3313
# L polynomial mod p:  [1, -88, -392, 960]
#       L polynomial:  [1, -88, 6234, -234263, 20653242, -965885272, 36363385297]
# _______________________________________
#              prime:  3319
# L polynomial mod p:  [1, 74, 735, -721]
#       L polynomial:  [1, 74, 10692, 473896, 35486748, 815166314, 36561310759]
# _______________________________________
#              prime:  3323
# L polynomial mod p:  [1, 0, 544, 0]
#       L polynomial:  [1, 0, 544, 0, 1807712, 0, 36693659267]
# _______________________________________
#              prime:  3329
# L polynomial mod p:  [1, 0, 715, 0]
#       L polynomial:  [1, 0, 715, 0, 2380235, 0, 36892780289]
# _______________________________________
#              prime:  3331
# L polynomial mod p:  [1, 30, 498, -418]
#       L polynomial:  [1, 30, 498, 6244, 1658838, 332866830, 36959313691]
# _______________________________________
#              prime:  3343
# L polynomial mod p:  [1, 125, -63, 1656]
#       L polynomial:  [1, 125, 9966, 666913, 33316338, 1396956125, 37360194607]
# _______________________________________
#              prime:  3347
# L polynomial mod p:  [1, 0, -279, 0]
#       L polynomial:  [1, 0, 9762, 0, 32673414, 0, 37494462923]
# _______________________________________
#              prime:  3359
# L polynomial mod p:  [1, 0, -8, 0]
#       L polynomial:  [1, 0, 3351, 0, 11256009, 0, 37899197279]
# _______________________________________
#              prime:  3361
# L polynomial mod p:  [1, -49, -1368, 917]
#       L polynomial:  [1, -49, -1368, 128635, -4597848, -553519729, 37966934881]
# _______________________________________
#              prime:  3371
# L polynomial mod p:  [1, 0, -801, 0]
#       L polynomial:  [1, 0, -801, 0, -2700171, 0, 38306833811]
# _______________________________________
#              prime:  3373
# L polynomial mod p:  [1, 134, 935, -828]
#       L polynomial:  [1, 134, 11054, 643415, 37285142, 1524535286, 38375056117]
# _______________________________________
#              prime:  3389
# L polynomial mod p:  [1, 0, -1374, 0]
#       L polynomial:  [1, 0, -1374, 0, -4656486, 0, 38923752869]
# _______________________________________
#              prime:  3391
# L polynomial mod p:  [1, -91, 948, -1422]
#       L polynomial:  [1, -91, -2443, 514010, -8284213, -1046398171, 38992705471]
# _______________________________________
#              prime:  3407
# L polynomial mod p:  [1, 0, 1551, 0]
#       L polynomial:  [1, 0, 8365, 0, 28499555, 0, 39547260143]
# _______________________________________
#              prime:  3413
# L polynomial mod p:  [1, 0, -537, 0]
#       L polynomial:  [1, 0, -537, 0, -1832781, 0, 39756565997]
# _______________________________________
#              prime:  3433
# L polynomial mod p:  [1, 19, 323, 1601]
#       L polynomial:  [1, 19, 323, -310802, 1108859, 223924291, 40459583737]
# _______________________________________
#              prime:  3449
# L polynomial mod p:  [1, 0, -398, 0]
#       L polynomial:  [1, 0, 3051, 0, 10522899, 0, 41027927849]
# _______________________________________
#              prime:  3457
# L polynomial mod p:  [1, 82, 567, 1125]
#       L polynomial:  [1, 82, -2890, -534710, -9990730, 979969618, 41314084993]
# _______________________________________
#              prime:  3461
# L polynomial mod p:  [1, 0, 1225, 0]
#       L polynomial:  [1, 0, 4686, 0, 16218246, 0, 41457661181]
# _______________________________________
#              prime:  3463
# L polynomial mod p:  [1, 1, 176, 764]
#       L polynomial:  [1, 1, 176, -293591, 609488, 11992369, 41529573847]
# _______________________________________
#              prime:  3467
# L polynomial mod p:  [1, 0, 77, 0]
#       L polynomial:  [1, 0, 3544, 0, 12287048, 0, 41673648563]
# _______________________________________
#              prime:  3469
# L polynomial mod p:  [1, 44, -1065, -515]
#       L polynomial:  [1, 44, -1065, -73364, -3694485, 529494284, 41745810709]
# _______________________________________
#              prime:  3491
# L polynomial mod p:  [1, 0, -855, 0]
#       L polynomial:  [1, 0, -855, 0, -2984805, 0, 42545099771]
# _______________________________________
#              prime:  3499
# L polynomial mod p:  [1, -156, 1730, 471]
#       L polynomial:  [1, -156, 15726, -1108712, 55025274, -1909908156, 42838260499]
# _______________________________________
#              prime:  3511
# L polynomial mod p:  [1, 15, -939, 1676]
#       L polynomial:  [1, 15, -939, -117698, -3296829, 184906815, 43280521831]
# _______________________________________
#              prime:  3517
# L polynomial mod p:  [1, 86, -612, 972]
#       L polynomial:  [1, 86, 6422, 271781, 22586174, 1063758854, 43502789413]
# _______________________________________
#              prime:  3527
# L polynomial mod p:  [1, 0, 385, 0]
#       L polynomial:  [1, 0, 3912, 0, 13797624, 0, 43874924183]
# _______________________________________
#              prime:  3529
# L polynomial mod p:  [1, -117, -395, 22]
#       L polynomial:  [1, -117, 6663, -381110, 23513727, -1457099397, 43949604889]
# _______________________________________
#              prime:  3533
# L polynomial mod p:  [1, 0, -1754, 0]
#       L polynomial:  [1, 0, 8845, 0, 31249385, 0, 44099220437]
# _______________________________________
#              prime:  3539
# L polynomial mod p:  [1, 0, -402, 0]
#       L polynomial:  [1, 0, -402, 0, -1422678, 0, 44324279819]
# _______________________________________
#              prime:  3541
# L polynomial mod p:  [1, 70, 48, 1370]
#       L polynomial:  [1, 70, -3493, -501452, -12368713, 877707670, 44399469421]
# _______________________________________
#              prime:  3547
# L polynomial mod p:  [1, 67, -1636, -23]
#       L polynomial:  [1, 67, -1636, -319253, -5802892, 842941003, 44625548323]
# _______________________________________
#              prime:  3557
# L polynomial mod p:  [1, 0, 1677, 0]
#       L polynomial:  [1, 0, -1880, 0, -6687160, 0, 45004049693]
# _______________________________________
#              prime:  3559
# L polynomial mod p:  [1, -7, 1565, -1129]
#       L polynomial:  [1, -7, 5124, -164843, 18236316, -88665367, 45080005879]
# _______________________________________
#              prime:  3571
# L polynomial mod p:  [1, -31, -1740, -1239]
#       L polynomial:  [1, -31, 8973, -190502, 32042583, -395313271, 45537538411]
# _______________________________________
#              prime:  3581
# L polynomial mod p:  [1, 0, -1047, 0]
#       L polynomial:  [1, 0, -1047, 0, -3749307, 0, 45921171941]
# _______________________________________
#              prime:  3583
# L polynomial mod p:  [1, -163, -445, 4]
#       L polynomial:  [1, -163, 10304, -490867, 36919232, -2092575907, 45998156287]
# _______________________________________
#              prime:  3593
# L polynomial mod p:  [1, 0, -1370, 0]
#       L polynomial:  [1, 0, 2223, 0, 7987239, 0, 46384368857]
# _______________________________________
#              prime:  3607
# L polynomial mod p:  [1, -9, -963, -708]
#       L polynomial:  [1, -9, -963, -137774, -3473541, -117094041, 46928689543]
# _______________________________________
#              prime:  3613
# L polynomial mod p:  [1, 57, -1357, 222]
#       L polynomial:  [1, 57, 2256, 263971, 8150928, 744064833, 47163267397]
# _______________________________________
#              prime:  3617
# L polynomial mod p:  [1, 0, 1789, 0]
#       L polynomial:  [1, 0, 5406, 0, 19553502, 0, 47320086113]
# _______________________________________
#              prime:  3623
# L polynomial mod p:  [1, 0, -39, 0]
#       L polynomial:  [1, 0, 7207, 0, 26110961, 0, 47555965367]
# _______________________________________
#              prime:  3631
# L polynomial mod p:  [1, -13, 657, -428]
#       L polynomial:  [1, -13, -2974, 155705, -10798594, -171394093, 47871688591]
# _______________________________________
#              prime:  3637
# L polynomial mod p:  [1, -31, -521, 1417]
#       L polynomial:  [1, -31, 3116, -158611, 11332892, -410060839, 48109395853]
# _______________________________________
#              prime:  3643
# L polynomial mod p:  [1, -196, -1530, -1106]
#       L polynomial:  [1, -196, 20328, -1465592, 74054904, -2601204004, 48347888707]
# _______________________________________
#              prime:  3659
# L polynomial mod p:  [1, 0, 1031, 0]
#       L polynomial:  [1, 0, -2628, 0, -9615852, 0, 48987720179]
# _______________________________________
#              prime:  3671
# L polynomial mod p:  [1, 0, -1642, 0]
#       L polynomial:  [1, 0, 2029, 0, 7448459, 0, 49471280711]
# _______________________________________
#              prime:  3673
# L polynomial mod p:  [1, 57, -98, -17]
#       L polynomial:  [1, 57, 7248, 220363, 26621904, 768982953, 49552182217]
# _______________________________________
#              prime:  3677
# L polynomial mod p:  [1, 0, 956, 0]
#       L polynomial:  [1, 0, 4633, 0, 17035541, 0, 49714249733]
# _______________________________________
#              prime:  3691
# L polynomial mod p:  [1, -93, -1466, 246]
#       L polynomial:  [1, -93, 5916, -306107, 21835956, -1266983733, 50284268371]
# _______________________________________
#              prime:  3697
# L polynomial mod p:  [1, 93, -249, 372]
#       L polynomial:  [1, 93, 10842, 558619, 40082874, 1271106237, 50529889873]
# _______________________________________
#              prime:  3701
# L polynomial mod p:  [1, 0, 1034, 0]
#       L polynomial:  [1, 0, -2667, 0, -9870567, 0, 50694081101]
# _______________________________________
#              prime:  3709
# L polynomial mod p:  [1, -150, -1448, 1411]
#       L polynomial:  [1, -150, 5970, -65351, 22142730, -2063502150, 51023529829]
# _______________________________________
#              prime:  3719
# L polynomial mod p:  [1, 0, 117, 0]
#       L polynomial:  [1, 0, 117, 0, 435123, 0, 51437343959]
# _______________________________________
#              prime:  3727
# L polynomial mod p:  [1, 116, -945, 1628]
#       L polynomial:  [1, 116, 10236, 836476, 38149572, 1611301364, 51770001583]
# _______________________________________
#              prime:  3733
# L polynomial mod p:  [1, 98, -1382, -1422]
#       L polynomial:  [1, 98, 6084, 203893, 22711572, 1365658322, 52020433837]
# _______________________________________
#              prime:  3739
# L polynomial mod p:  [1, 69, -732, 992]
#       L polynomial:  [1, 69, -732, -182219, -2736948, 964628349, 52271672419]
# _______________________________________
#              prime:  3761
# L polynomial mod p:  [1, 0, 1673, 0]
#       L polynomial:  [1, 0, 9195, 0, 34582395, 0, 53199800081]
# _______________________________________
#              prime:  3767
# L polynomial mod p:  [1, 0, 1211, 0]
#       L polynomial:  [1, 0, 8745, 0, 32942415, 0, 53454818663]
# _______________________________________
#              prime:  3769
# L polynomial mod p:  [1, -67, -910, 450]
#       L polynomial:  [1, -67, 2859, -301070, 10775571, -951759187, 53540005609]
# _______________________________________
#              prime:  3779
# L polynomial mod p:  [1, 0, -369, 0]
#       L polynomial:  [1, 0, 7189, 0, 27167231, 0, 53967298139]
# _______________________________________
#              prime:  3793
# L polynomial mod p:  [1, 168, -1025, 1221]
#       L polynomial:  [1, 168, 17940, 1233946, 68046420, 2416990632, 54569318257]
# _______________________________________
#              prime:  3797
# L polynomial mod p:  [1, 0, 1349, 0]
#       L polynomial:  [1, 0, 8943, 0, 33956571, 0, 54742142573]
# _______________________________________
#              prime:  3803
# L polynomial mod p:  [1, 0, 1112, 0]
#       L polynomial:  [1, 0, 8718, 0, 33154554, 0, 55002062627]
# _______________________________________
#              prime:  3821
# L polynomial mod p:  [1, 0, 579, 0]
#       L polynomial:  [1, 0, 579, 0, 2212359, 0, 55786756661]
# _______________________________________
#              prime:  3823
# L polynomial mod p:  [1, -109, 205, -80]
#       L polynomial:  [1, -109, 4028, -88009, 15399044, -1593070861, 55874402767]
# _______________________________________
#              prime:  3833
# L polynomial mod p:  [1, 0, 1177, 0]
#       L polynomial:  [1, 0, 5010, 0, 19203330, 0, 56314010537]
# _______________________________________
#              prime:  3847
# L polynomial mod p:  [1, 98, -1211, -907]
#       L polynomial:  [1, 98, 2636, -93235, 10140692, 1450342082, 56933326423]
# _______________________________________
#              prime:  3851
# L polynomial mod p:  [1, 0, -1740, 0]
#       L polynomial:  [1, 0, 9813, 0, 37789863, 0, 57111104051]
# _______________________________________
#              prime:  3853
# L polynomial mod p:  [1, -10, -1531, -537]
#       L polynomial:  [1, -10, 2322, -389690, 8946666, -148456090, 57200131477]
# _______________________________________
#              prime:  3863
# L polynomial mod p:  [1, 0, 1358, 0]
#       L polynomial:  [1, 0, 5221, 0, 20168723, 0, 57646656647]
# _______________________________________
#              prime:  3877
# L polynomial mod p:  [1, -54, -691, -635]
#       L polynomial:  [1, -54, 3186, -12266, 12352122, -811680966, 58275687133]
# _______________________________________
#              prime:  3881
# L polynomial mod p:  [1, 0, 1255, 0]
#       L polynomial:  [1, 0, 5136, 0, 19932816, 0, 58456246841]
# _______________________________________
#              prime:  3889
# L polynomial mod p:  [1, 47, 1263, 1507]
#       L polynomial:  [1, 47, -2626, -496285, -10212514, 710843087, 58818484369]
# _______________________________________
#              prime:  3907
# L polynomial mod p:  [1, 108, 718, 1046]
#       L polynomial:  [1, 108, 8532, 618352, 33334524, 1648582092, 59638983643]
# _______________________________________
#              prime:  3911
# L polynomial mod p:  [1, 0, -1286, 0]
#       L polynomial:  [1, 0, -1286, 0, -5029546, 0, 59822347031]
# _______________________________________
#              prime:  3917
# L polynomial mod p:  [1, 0, 1043, 0]
#       L polynomial:  [1, 0, 4960, 0, 19428320, 0, 60098096213]
# _______________________________________
#              prime:  3919
# L polynomial mod p:  [1, 14, -864, 1579]
#       L polynomial:  [1, 14, 6974, -18016, 27331106, 215019854, 60190200559]
# _______________________________________
#              prime:  3923
# L polynomial mod p:  [1, 0, 1617, 0]
#       L polynomial:  [1, 0, 1617, 0, 6343491, 0, 60374691467]
# _______________________________________
#              prime:  3929
# L polynomial mod p:  [1, 0, -1881, 0]
#       L polynomial:  [1, 0, -1881, 0, -7390449, 0, 60652134089]
# _______________________________________
#              prime:  3931
# L polynomial mod p:  [1, -74, -1470, -493]
#       L polynomial:  [1, -74, 6392, -653039, 25126952, -1143504314, 60744803491]
# _______________________________________
#              prime:  3943
# L polynomial mod p:  [1, 103, -1774, 300]
#       L polynomial:  [1, 103, -1774, -539891, -6994882, 1601366647, 61302802807]
# _______________________________________
#              prime:  3947
# L polynomial mod p:  [1, 0, 1828, 0]
#       L polynomial:  [1, 0, 1828, 0, 7215116, 0, 61489559123]
# _______________________________________
#              prime:  3967
# L polynomial mod p:  [1, -35, 663, 972]
#       L polynomial:  [1, -35, 8597, -292586, 34104299, -550798115, 62429032063]
# _______________________________________
#              prime:  3989
# L polynomial mod p:  [1, 0, -432, 0]
#       L polynomial:  [1, 0, 7546, 0, 30100994, 0, 63473450669]
# _______________________________________
#              prime:  4001
# L polynomial mod p:  [1, 0, 229, 0]
#       L polynomial:  [1, 0, 4230, 0, 16924230, 0, 64048012001]
# _______________________________________

# %%
from math import sqrt
import time
import re

def findLpolys(path, lowerlimit, limit):
    #Reading file for L polys modulo p
    #They are stored as lists of the form [p, 1, a1, a2, a3] after reading the file.

    polyL = []
    i = 0
    limit = prime_pi(limit) #convert into line numbers.
    
    with open(path, 'r') as file_handle:
        for line in file_handle:
            if(i==0):
                
                #Read off coefficients of the curve to store in C. The following is to format the defining polynomial.
                
                s = line[:-1]
                poly = re.match(r"[^[]*\[([^]]*)\]", s).groups()[0]
                list_coef = []
                poly = poly.replace(" ", "")
                
                #Now that it is formatted nicely, we read off the coefficients we want.
                
                for j in range(len(poly)):
                    if(poly[j]=='+' or poly[j]=='-'): 
                        s=poly[j]
                        k=1
                        while poly[j+k].isdigit(): 
                            s+=poly[j+k]
                            k+=1
                        if(len(s)>1): list_coef.append(int(s))
                
                #The three nonzero numbers are (in the affine part) the constant, x, x^2 coefficients in that order.
                #We use this format because this is how the Jacobian addition code formats the curve.
                
                C = [list_coef[2],list_coef[1],list_coef[0],0,0,0,0]
            i+=1
            if(i>1 and i<=limit):
                line = line[:-1].split(",")
                polyL.append([int(line[0]), 1, int(line[1]), int(line[2]), int(line[3])])
            elif(i>1):
                break
            
    #polyL now has the full list.
    
    print "======================================="
    print "Data for the curve y^3 = x^4 + ", int(C[2]),"x^2 + ",int(C[1]),"x + ",int(C[0])
    print "======================================="
    
    ret = []
    
    print "starting"
    T1 = time.time()
    
    for pcoeffs in polyL:
        p = pcoeffs[0]
        coeffs = pcoeffs[1:]
        if p >= lowerlimit:
            answer=[coeffs,p,liftLpoly(coeffs, p, C)]
            ret.append(answer)
    T2 = time.time()
    
    print "done in "+str(T2-T1)+" seconds"
    print "average time "+str((T2-T1)/len(ret))+" seconds"
    return ret

def liftLpoly(coeffs, p, C):
    if p<=151:
        return "Not implemented here."
        #Small cases not relevant.
        
    elif(p%3==1):
        #S will store possible a_i triples
        S=[]
        a1count = 0
        A_1 = coeffs[1]
        K.<w>=NumberField(x^2+3)
        X=K(p).factor()
        pi=X[0][0]
        pibar=X[1][0]
        
        #Factor p over Q(zeta_3) as p = pi * pibar.

        zeta = 1/2 * (1+w)
        
        #zeta is a cube root of unity.
        
        units = [zeta^i for i in range(6)]
        
        #units is the unit group of Q(zeta_3).

        if(A_1^2>36*p):
            A_1 = Mod(A_1,p)
            A_1 = ZZ(A_1)
            if(A_1^2 > 36*p):
                A_1 -= p

        #A_1 is now its true value since p>149.

        #Construct a_3 values.
        
        a3vals = []
        for u in units:
            a3vals.append(pi^3 * u)
            a3vals.append(pi^2 * pibar * u)

        #Store A_2, A_3 modulo p.
        
        A_2modp = coeffs[2]
        A_3modp = coeffs[3]

        #Loop over possible A_2 values.

        for i in range(32):
            A_2 = A_2modp + (-1)^i*floor((i+1)/2)*p
            
            #This looping structure is so that we start near 0; the actual A_2 is likely to be here.
            #This saves time if we are only outputting the first L polynomial we get (|S|=1 most of the time).
            #The code is easily modified to do this.
            
            for a3 in a3vals:
                a3bar = a3[0]-w*a3[1]
                
                #Secretly, we are setting:
                #a1    = -A_1/2 + t*w
                #a1bar = -A_1/2 - t*w

                #a2    = 1/p * (a1bar*a3)
                #a2bar = 1/p * (a1*a3bar)

                #f = (a2+a2bar)+a1*a1bar-A_2

                #Coefficients of f are a,b,c, as given below.
                #Below, we skip these steps to avoid the cost of constructing a polynomial ring.
                
                #This solves the first congruence over K.

                a = 3
                b = 1/p*(-a3+a3bar)*w
                c = A_1^2/4-(a3+a3bar)*A_1/(2*p)-A_2

                #Discriminant of f.
                
                Delta = b^2-4*a*c

                #Stores roots of f (if valid).
                
                R=[]

                #The following checks look for half-integer roots. Any other roots are invalid.
                #If this is the case, the disciminant should be a square in Q; there are two cases.

                if(Delta >= 0 and b in ZZ and Delta in ZZ):
                    
                    delta = sqrt(Delta)

                    if(delta.is_integer()):
                        
                        delta = ZZ(delta)
                        R = [1/(2*a)*(-b+delta),1/(2*a)*(-b-delta)]

                elif(Delta >= 0 and p*b in ZZ and p^2*Delta in ZZ):
                    
                    delta = sqrt(p^2*Delta)
                    
                    if(delta.is_integer()): 
                        delta=ZZ(delta)
                        R = [1/(2*a)*(-b+delta/p),1/(2*a)*(-b-delta/p)]

                for r in R:
                    
                    #This solves the second congruence.
                    A = Mod(A_3modp,p)
                    
                    a1 = -A_1/2 + r*w
                    a1bar = -A_1/2 - r*w
                    a2    = 1/p * (a1bar*a3)
                    a2bar = 1/p * (a1*a3bar)
                    
                    A3check = (-(a3+a3bar)-(a1*a2bar+a1bar*a2))
                    
                    if(A3check in ZZ and 2*r in ZZ):
                        
                        B = Mod(A3check,p)
                        
                        if(A == B and abs(RR(r/p)) < 3*RR(1/sqrt(p))):
                            A_3 = -a2*a1bar-a1*a2bar-a3-a3bar
                            #return [1, A_1, A_2, A_3, p*A_2, p^2*A_1, p^3]
                            #For fast evaluation on generic curve
                            S.append([1, A_1, A_2, A_3, p*A_2, p^2*A_1, p^3])
                            #print a3
                            #for u in units:
                                #if(u*pi*p == a3): print K.ideal(3).reduce(u*pi)
        retS=[]
        for elem in S:
            if elem not in retS:
                retS.append(elem)
        
        #This eliminates duplicates in S. 
        #In cases where C is not absolutely simple, i.e. a product of elliptic curves,
        #we can get multiple factorizations of L_p(t).
        #print(len(retS))
        
        if(len(retS)==1): return retS[0] #This must be the L polynomial.
        else:
            #We are in a rare case where |S|>1. We apply Algorithm 1 below.
            #Most of the time this resolves the issue in O(log^2 p) time, avoiding the O(p^1/4) algorithm.
            #However, even without this (i.e. just skipping to O(p^1/4)) the average time should be polylogarithmic.
            jacvals = []
            k = GF(p)
            numruns = 0
            for s in retS:
                jacvals.append([ZZ(sum(s)),s])
            
            l = len(bin(p**3))-1

            while(len(jacvals)>1):
            
                D = makeRandomDiv(C,k)
                Dpows = Dpowers(l,D,C)
                count=0
                numruns+=1

                if(numruns > 10): 
                    return "Use O(p^1/4) algorithm instead."

                while count<(len(jacvals)):

                    Jac = jacvals[count]

                    N_1D = multbyN(Jac[0]-1,D,Dpows,C)

                    if(eqZero(N_1D,D,C,k)==False):

                        jacvals.remove(Jac)

                    else: count+=1

        return jacvals[0][1]
    else:
        if(coeffs==[1,0,0,0]): return "Use O(p^1/4) algorithm instead."
        A_1 = 0
        A_3 = 0
        #A_1,A_3 are now correct
        
        #L_p(t) = (pt^2+1)(p^2 t^4+(a/2)t^2-pt^2+1). So A_1=0, A_3=0. A_2=a/2.
        
        A_2modp = coeffs[2]
        k = GF(p)
        jacvals=[]
        
        for i in range(30):
                A_2 = A_2modp + (-1)^i*floor((i+1)/2)*p
                JC = 1+A_2+A_2*p+p^3
                jacvals.append([JC, [1,0,A_2,0,p*A_2,0,p^3]])
                    
        l = len(bin(1+31*p+31*p**2+p**3))-2
        numruns = 0
        
        #Implementation of Algorithm 1 from the paper.
        #Expected polylog time for a generic curve.
        #If the number of runs is large, it is very unlikely we are in a 'good' case
        #In this case, we output that we should use another algorithm.
        
        while(len(jacvals)>1):
            
            D = makeRandomDiv(C,k)
            Dpows = Dpowers(l,D,C)
            count=0
            numruns+=1
            
            if(numruns > 10): 
                return "Use O(p^1/4) algorithm instead."
            
            while count<(len(jacvals)):
                
                Jac = jacvals[count]
                
                N_1D = multbyN(Jac[0]-1,D,Dpows,C)

                if(eqZero(N_1D,D,C,k)==False):
                    
                    jacvals.remove(Jac)
                    
                else: count+=1

        return jacvals[0][1]

# %%
#For divisors

def makeRandomDiv(C,k):
    #Implementation of Algorithm 3 from the paper.
    R.<x> = k[]
    
    uv = [0,0]
    
    uprod = 1
    
    while(True):
        
        a = k.random_element()
        while(a==0):
            a = k.random_element() #We don't want a=0. Will create division by zero errors in other places.
        b = k.random_element()
        c = k.random_element()
        
        #f = y^3 - (C[0]+C[1]*x+C[2]*x^2+x^4)
        #v = a*x^2 + b*x + c
        
        #Below, we use an explicit formula for bigu = f(x,v)
        
        bigu = x^6*a^3 + 3*x^5*a^2*b + 3*x^4*a*b^2 + 3*x^4*a^2*c + x^3*b^3 + 6*x^3*a*b*c + 3*x^2*b^2*c + 3*x^2*a*c^2 + 3*x*b*c^2 + c^3 - x^4 - C[2]*x^2 - C[1]*x - C[0]

        factors = R(bigu).roots()
        
        #We want to construct u from degree one factors, so that its roots are distinct.
        
        if(len(factors)>=3):
            factors = factors[:3]
            for u in factors:
                uprod*=R((x-u[0]))
            uv = [[1,uprod[2],uprod[1],uprod[0]], [a,b,c]]
                
            #Return Mumford representation (u,v)
            
            return [uv[0][3], uv[0][2], uv[0][1], uv[1][2], uv[1][1], uv[1][0]]
        uprod=1

def eqZero(N_1D,D,C,k):
    #Returns if N_1D and D are additive inverses.
    Dinv = [0,0,0,0,0,0]
    Dinv[3] = D[3]
    Dinv[4] = D[4]
    Dinv[5] = D[5]
    a = D[5]
    b = D[4]
    c = D[3]
    B = isTypical(N_1D,C,k)
    
    if(Dinv[3:]!= N_1D[3:] and B):
        return False
    
    R.<x>=k[]
    
    bigu = x^6*a^3 + 3*x^5*a^2*b + 3*x^4*a*b^2 + 3*x^4*a^2*c + x^3*b^3 + 6*x^3*a*b*c + 3*x^2*b^2*c + 3*x^2*a*c^2 + 3*x*b*c^2 + c^3 - x^4 - C[2]*x^2 - C[1]*x - C[0]

    quopoly = R(1/a^3 * bigu/(x^3 + D[2]*x^2 + D[1]*x + D[0]))
    
    Dinv[0] = quopoly[0]
    Dinv[1] = quopoly[1]
    Dinv[2] = quopoly[2]
    
    if(Dinv == N_1D and B): return True
    if(Dinv == N_1D and B==False): return True
    if(Dinv != N_1D and B): return False
    if(Dinv != N_1D and B==False): return True
    
def isTypical(D,C,k):
    R.<x> = k[]
    A.<x,y> = k[]
    polyu = x^3 + D[2]*x^2 + D[1]*x + D[0]
    polyv = D[5]*x^2 + D[4]*x + D[3]
    #u,v polynomials in representation of divisor.
    curve = y^3 - (C[0]+C[1]*x+C[2]*x^2+x^4)
    return (curve(x,polyv)%polyu == 0) 

#For order computations.

def Dpowers(l,D,C):
    Dpows = [D]
    
    for i in range(l-1):
        Dtemp = Dpows[len(Dpows)-1]
        D = double(Dtemp, C)
        Dpows.append(D)
    #Dpows now has all needed powers of 2^k D.
    return Dpows

def multbyN(N,D,Dpows,C):
    #f0 = C[0]
    #f1 = C[1]
    #f2 = C[2]
    #h0 = C[3]
    #h1 = C[4]
    #h2 = C[5]
    #h3 = C[6]
    #Fast conversion to binary.
    binaryN = bin(N)[2:]
    #Store log_2 N
    l = len(binaryN)
    #Store powers.
    Dtemp = []
    
    for i in range(l):
        D = Dpows[l-1-i]
        if(binaryN[i]=='1'):
            if(Dtemp == []): Dtemp = D
            else: Dtemp = add(D,Dtemp, C)
                
    return Dtemp

# %%
#This section is not our code. 
#It is a translated version of code written by Stephane Flon, Roger Oyono, and Christophe Ritzenthaler.
#See https://gaati.org/oyono/ArithmeticQuartics.html for the original code.

# ***************************************************************************
# ***************************************************************************
# ***************************************************************************


def mulconst (a, c):
   # returns c*a, where a is supposed to be a field element and c a small
   # constant. Put into a separate def so that each occurrence of
   # "*" in the formulae corresponds to a multiplication of two field
   # elements. It should normally be computed by repeated additions to
   # simplify, we use a multiplication here.
   return c*a


def divconst (a, c):
   # returns a/c, where a is supposed to be a field element and c a small
   # constant. It should normally be computed in a special way, see our
   # article to simplify, we use a normal division here.
   return a/c

def invert(a):
    if(a!=0):
        return 1/a
    else:
        return 0

# ***************************************************************************
# ***************************************************************************
# ***************************************************************************

def toom_cook_1_1 (X0,X1,Y0,Y1):
# Let W = X * Y first multiply without the leading coefficient by
# Cost: 3M
# interpolation on 0, 1 and infinity

    Xval1  = X1 + X0
    Yval1  = Y1 + Y0

# Evaluate

    Wval0   = X0 * Y0
    Wval1   = Xval1 * Yval1
    Wvalinf = X1*Y1

# Interpolate

    W2 = Wvalinf
    W0 = Wval0
    W1 = Wval1 - (W0+W2)

    return W0,W1,W2

# ***************************************************************************
def interpolate(X0, X1, Xm1, Xinf):

# Cost:    for free
# interpolation on 0, 1, -1  and infinity

# Interpolate

    W3 = Xinf
    W0 = X0
    W2 = divconst(X1 + Xm1, 2) - W0
    W1 = X1 - ( W0 + W2 + W3 )
    
    return W0,W1,W2,W3

def toom_cook_1_1 (X0,X1,Y0,Y1):
# Let W = X * Y first multiply without the leading coefficient by
# interpolation on 0, 1 and infinity

    Xval1  = X1 + X0
    Yval1  = Y1 + Y0

# Evaluate

    Wval0   = X0 * Y0
    Wval1   = Xval1 * Yval1
    Wvalinf = X1*Y1

# Interpolate

    W2 = Wvalinf
    W0 = Wval0
    W1 = Wval1 - ( W0 + W2)

    return W0,W1,W2

# ***************************************************************************


def toom_cook_1_2 (X0,X1,Y0,Y1,Y2):
# Let W = X * Y first multiply without the leading coefficient by
# Cost: 4M
# interpolation on 0, 1, -1  and infinity

    Xval1  = X1 + X0
    Yval1  = Y2 + Y1 + Y0
    Xvalm1 = - X1 + X0
    Yvalm1 = Y2 - Y1 + Y0

# Evaluate

    Wval0   = X0 * Y0
    Wval1   = Xval1 * Yval1
    Wvalm1  = Xvalm1 * Yvalm1
    Wvalinf = X1*Y2

# Interpolate

    W3 = Wvalinf
    W0 = Wval0
    W2 = divconst(Wval1+Wvalm1,2) - W0
    W1 = Wval1 - ( W0 + W2 + W3 )

    return W0,W1,W2,W3

# ***************************************************************************

def toom_cook_1_3 (X0,X1,Y0,Y1,Y2,Y3):
# Let W = X * Y first multiply without the leading coefficient by
# Cost: 5M
# interpolation on 0, 1, -1, 2  and infinity

    Xval1  = X1 + X0
    Yval1  = Y3 + Y2 + Y1 + Y0
    Xvalm1 = - X1 + X0
    Yvalm1 = - Y3 + Y2 - Y1 + Y0
    Xval2  = mulconst(X1,2) + X0
    Yval2  = mulconst (Y3, 8) + mulconst (Y2, 4) + mulconst (Y1, 2) + Y0
#Yval2  = mulconst ( mulconst ( mulconst (Y3, 2) + Y2, 2) + Y1,2) + Y0

# Evaluate

    Wval0   = X0 * Y0
    Wval1   = Xval1 * Yval1
    Wvalm1  = Xvalm1 * Yvalm1
    Wval2   = Xval2 * Yval2
    Wvalinf = X1*Y3

# Interpolate

    W4 = Wvalinf
    W0 = Wval0
    W2 = -(Wval0 + Wvalinf) + divconst(Wval1 + Wvalm1,2)
    W3 = - mulconst(Wvalinf,2) + divconst(Wval0 - Wval1 + divconst(Wval2 - Wvalm1,3),2)
    W1 = Wval1 - ( W0 + W2 + W3 + W4)

    return W0,W1,W2,W3,W4

# ***************************************************************************

def toom_cook_2_2 (X0,X1,X2,Y0,Y1,Y2):
# Let W = X * Y first multiply without the leading coefficient by
# Cost: 5M
# interpolation on 0, 1, -1, 2 and infinity

    Xval1  = X2 + X1 + X0
    Yval1  = Y2 + Y1 + Y0
    Xvalm1 = X2 - X1 + X0
    Yvalm1 = Y2 - Y1 + Y0
    Xval2  = mulconst (X2, 4) + mulconst (X1, 2) + X0
    Yval2 =  mulconst (Y2, 4) + mulconst (Y1, 2) + Y0
#Xval2  = mulconst (mulconst (X2, 2) + X1, 2) + X0
#Yval2  = mulconst (mulconst (Y2, 2) + Y1, 2) + Y0

# Evaluate

    Wval0   = X0 * Y0
    Wval1   = Xval1 * Yval1
    Wvalm1  = Xvalm1 * Yvalm1
    Wval2   = Xval2 * Yval2
    Wvalinf = X2*Y2

# Interpolate

    W4 = Wvalinf
    W0 = Wval0
    W2 = divconst (Wval1 + Wvalm1, 2) - (W0 + W4)
    W3 = divconst (divconst (Wval2 - Wval1 + Wvalm1 - W0, 2) - mulconst (mulconst (W4, 4) + W2, 2), 3)
    W1 = Wval1 - ( W0 + W2 + W3 + W4 )

    return W0,W1,W2,W3,W4

# ***************************************************************************

def toom_cook_square_2 (X0,X1,X2):
# Let W = X**2  first multiply without the leading coefficient by
#   5SQ

# interpolation on 0, 1, -1, 2 and infinity

    Xval1  = X2 + X1 + X0
    Xvalm1 = X2 - X1 + X0
    Xval2  = mulconst (X2, 4) + mulconst (X1, 2) + X0
#Xval2  = mulconst (mulconst (X2, 2) + X1, 2) + X0

# Evaluate

    Wval0   = X0**2
    Wval1   = Xval1**2
    Wvalm1  = Xvalm1**2
    Wval2   = Xval2**2
    Wvalinf = X2**2

# Interpolate

    W4 = Wvalinf
    W0 = Wval0
    W2 = divconst (Wval1 + Wvalm1, 2) - (W0 + W4)
    W3 = divconst (divconst (Wval2 - Wval1 + Wvalm1 - W0, 2) - mulconst (mulconst (W4, 4) + W2, 2), 3)
    W1 = Wval1 - ( W0 + W2 + W3 + W4 )

    return W0,W1,W2,W3,W4

def toom_cook_2_3 (X0,X1,X2,Y0,Y1,Y2,Y3):
# Let W = X * Y first multiply without the leading coefficient by
# interpolation on 0, 1, -1, 2 , -2 and infinity

    Xval1  =  X2 + X1 + X0
    Yval1  =  Y3 + Y2 + Y1 + Y0
    Xvalm1 =  X2 - X1 + X0
    Yvalm1 = -Y3 + Y2 - Y1 + Y0
    Xval2  =  mulconst (X2, 4) + mulconst (X1, 2) + X0
    Yval2  =  mulconst (Y3, 8) + mulconst (Y2, 4) + mulconst (Y1, 2) + Y0
    Xvalm2 =  mulconst (X2, 4) - mulconst (X1, 2) + X0
    Yvalm2 = -mulconst (Y3, 8) + mulconst (Y2, 4) - mulconst (Y1, 2) + Y0

#Evaluate

    Wval0   = X0*Y0
    Wval1   = Xval1*Yval1
    Wvalm1  = Xvalm1*Yvalm1
    Wval2   = Xval2*Yval2
    Wvalm2  = Xvalm2*Yvalm2
    Wvalinf = X2*Y3

# interpolate

    W0 = Wval0
    W5 = Wvalinf
    W3 = -mulconst(Wvalinf,5) + divconst(divconst(Wvalm1 - Wval1 + divconst(Wval2 - Wvalm2,2),2),3)
    W4 = divconst(divconst(-(Wval1 + Wvalm1)+ divconst( mulconst(Wval0, 3) + divconst(Wval2 + Wvalm2,2) ,2) ,2),3)
    W2 = divconst( Wval1 + Wvalm1, 2) -( W0 + W4 )
    W1 = Wval1 - ( W0 + W3 + W2 + W4 + W5 )

    return W0,W1,W2,W3,W4,W5

# ***************************************************************************

def toom_cook_3_3 (X0,X1,X2,X3,Y0,Y1,Y2,Y3):
# Let W = X * Y first multiply without the leading coefficient by
# interpolation on 0, 1, -1, 2 , -2, 3 and infinity
# 7M

    Xval1  =  X3 + X2 + X1 + X0
    Yval1  =  Y3 + Y2 + Y1 + Y0
    Xvalm1 = -X3 + X2 - X1 + X0
    Yvalm1 = -Y3 + Y2 - Y1 + Y0
    Xval2  =  mulconst (X3, 8) + mulconst (X2, 4) + mulconst (X1, 2) + X0
    Yval2  =  mulconst (Y3, 8) + mulconst (Y2, 4) + mulconst (Y1, 2) + Y0
    Xvalm2 = -mulconst (X3, 8) + mulconst (X2, 4) - mulconst (X1, 2) + X0
    Yvalm2 = -mulconst (Y3, 8) + mulconst (Y2, 4) - mulconst (Y1, 2) + Y0
    Xval3  =  mulconst (X3, 27)+ mulconst (X2, 9) + mulconst (X1, 3) + X0
    Yval3  =  mulconst (Y3, 27)+ mulconst (Y2, 9) + mulconst (Y1, 3) + Y0

#Evaluate

    Wval0   = X0*Y0
    Wval1   = Xval1*Yval1
    Wvalm1  = Xvalm1*Yvalm1
    Wval2   = Xval2*Yval2
    Wvalm2  = Xvalm2*Yvalm2
    Wval3   = Xval3*Yval3
    Wvalinf = X3*Y3

# interpolate

    W0 = Wval0
    W6 = Wvalinf
    W4 = -mulconst(Wvalinf,5) + divconst(divconst(-(Wval1+Wvalm1) + divconst(mulconst(Wval0,3) + divconst(Wvalm2+Wval2,2),2),2),3)
    W3 = mulconst(mulconst(Wvalinf,3),5) + divconst(divconst(divconst( mulconst(Wval0,5)  - mulconst(Wval1,7) +divconst(- Wval3 + mulconst(Wval2,7) - Wvalm2 - Wvalm1,2),2),2),3)#3
    W5 = -mulconst(Wvalinf,3) + divconst(divconst(divconst(Wval1-Wval0 + divconst(Wvalm1-Wval2+ divconst(Wval3-Wvalm2,5),2),2),2),3)
    W2 = divconst( Wval1 + Wvalm1, 2) -( W0 + W4 + W6)
    W1 = Wval1 - ( W0 + W2 + W3 + W4 + W5 + W6 )

    return W0,W1,W2,W3,W4,W5,W6

# ***************************************************************************


# ***************************************************************************
# ***************************************************************************
# ***************************************************************************

def modular_inverse_3n_2 (u0, u1, u2, v0, v1, v2):
# For u= x**3 + u2*x**2 + u1*x + u0 and v= v2*x**2 + v1*x + v0
# Compute d = gcd (u, v) and s
# such that d = (something)*u + s*v
# note that d is not i.g. the resultant(u,v).

# Cost  13M + 2SQ

# First pseudodivision quotient into q interpolation on
# 0, 1 for remainder r

    uval1 = u2 + u1 + u0
    vval1 = v2 + v1 + v0

    q1 = v2
    q0 = v2 * u2 - v1
    lc2 = v2**2
    r0 = lc2 * u0 - q0 * v0
    r1 = lc2 * (uval1 + 1) - (q1 + q0) * (vval1) - r0
# Second pseudodivision quotient into Q, remainder into d
    Q1 = r1 * v2
    Q0 = r1 * v1 - r0 * v2
    lc2 = r1**2
    d = lc2 * v0 - Q0 * r0
# s = lc2 + Q q
    s0 = q0 * Q0
    s2 = q1 * Q1
    s1 = (q0 + q1) * (Q0 + Q1) - s0 - s2
    s0 = s0 + lc2

    return  s0,s1,s2,d

def modular_inverse_3n_4 (u0, u1, u2, c0, c1, c2, c3, c4):
# For u= x**3 + u2*x**2 + u1*x + u0 and c= c4*x**4 + c3*x**3 + c2*x**2 + c1*x + c0
# Compute d = gcd (u, v) and s
# such that d = (something)*u + s*v
# note that d is not i.g. the resultant(u,v).
# 17M +2SQ

# Euclidian algorithm between c and u

# q1 = quotient of c by u
    q11 = c4
    q10 = c3 - c4 * u2
# r1 = c - q1 u by interpolation on 0, 1, -1
    r10 = c0 - q10 * u0
    uval1 = 1 + u2 + u1 + u0
    uvalm1 = -1 + u2 - u1 + u0
    val1 = c4 + c3 + c2 + c1 + c0 - (q11 + q10) * uval1
    valm1 = c4 - c3 + c2 - c1 + c0 - (q10 - q11) * uvalm1
    r11 = divconst (val1 - valm1, 2)
    r12 = val1 - r11 - r10
# q2 = quotient of r12**2 u by r1
    q21 = r12
    q20 = r12 * u2 - r11
# r2 = r12**2 u - q2 r1 by interpolation on 0 and 1
    lc2 = r12**2
    r20 = lc2 * u0 - q20 * r10
    r21 = lc2 * uval1 - (q21 + q20) * (r12 + r11 + r10) - r20
# q3 = quotient of r21**2 r1 by r2
    q31 = r21 * r12
    q30 = r21 * r11 - r20 * r12
    lc2 = r21**2
    d = lc2 * r10 - q30 * r20
# s = r21**2 + q2 q3
    s0 = q20 * q30
    s2 = q21 * q31
    s1 = (q21 + q20) * (q31 + q30) - s0 - s2
    s0 = s0 + lc2

    return s0,s1,s2,d

def modular_inverse_3n_3 (u0, u1, u2, c0, c1, c2, c3):
# For u= x**3 + u2*x**2 + u1*x + u0 and c=  c3*x**3 + c2*x**2 + c1*x + c0
# Compute d = gcd (u, v) and s
# such that d = (something)*u + s*v
# note that d is not i.g. the resultant(u,v).

# 16M + 2SQ

# Euclidian algorithm between c and u

# q1 = quotient of c by u

    q10 = c3
# r1 = c - q1 u by interpolation on 0, 1, -1
    r10 = c0 - q10 * u0
    uval1 = 1 + u2 + u1 + u0
    uvalm1 = -1 + u2 - u1 + u0
    val1 = c3 + c2 + c1 + c0 - q10 * uval1
    valm1 = - c3 + c2 - c1 + c0 - q10 * uvalm1
    r11 = divconst (val1 - valm1, 2)
    r12 = val1 - r11 - r10
# q2 = quotient of r12**2 u by r1
    q21 = r12
    q20 = r12 * u2 - r11
# r2 = r12**2 u - q2 r1 by interpolation on 0 and 1
    lc2 = r12**2
    r20 = lc2 * u0 - q20 * r10
    r21 = lc2 * uval1 - (q21 + q20) * (r12 + r11 + r10) - r20
# q3 = quotient of r21**2 r1 by r2
    q31 = r21 * r12
    q30 = r21 * r11 - r20 * r12
    lc2 = r21**2
    d = lc2 * r10 - q30 * r20
# s = r21**2 + q2 q3
    s0 = q20 * q30
    s2 = q21 * q31
    s1 = (q21 + q20) * (q31 + q30) - s0 - s2
    s0 = s0 + lc2

    return s0,s1,s2,d

# ***************************************************************************
# ***************************************************************************
# ***************************************************************************

def remainder_4_3n (t0, t1, t2, t3, t4, u0, u1, u2):
# For u= x**3 + u2*x**2 + u1*x + u0 and t= t4*x**4 + t3*x**3 + t2*x**2 + t1*x + t0
# Compute Remainder(t,u)
#Cost 4M

    uval1  = u2 + u1 + u0
    uvalm1 = u2 - u1 + u0

# q = quotient of t by u
    q1 = t4
    q0 = t3 - t4 * u2
    # t = t - q u
    T0 = t0 - q0 * u0
    tval1  = (t4 + t3 + t2 + t1 + t0) - (q0 + q1) * (uval1 + 1)
    tvalm1 = (t4 - t3 + t2 - t1 + t0) - (q0 - q1) * (uvalm1 - 1)
    T1 = divconst (tval1 - tvalm1, 2)
    T2 = tval1 - T0 - T1

    return  T0,T1,T2

# ***************************************************************************
# ***************************************************************************

def quotient_6n_3n (u3, u4, u5, v0, v1, v2):
# For u= x**6 + u5*x**5 + u4*x**4 + u3 + ... and v= x**3 + v2*x**2 + v1*x + v0
# or for u= x**9 + u5*x**8 + u4*x**7 + u3 * x**6 + ... and v= x**6 + v2*x**5 + v1*x**4 + v0*x**3
# Compute Quotient(u,v)
#Cost 3M

    q2 = u5 - v2
    q1 = u4 - v1 - v2 * q2
    r1 = u3 - v0 - v1 * (u5 - v2)
    q0 = - v2 * q1 + r1

    return  q0,q1,q2

#Addition of divisors.

def add(D1, D2, C):

    u10 = D1[0] 
    u11 = D1[1] 
    u12 = D1[2] 

    v10 = D1[3] 
    v11 = D1[4] 
    v12 = D1[5] 


    u20 = D2[0] 
    u21 = D2[1] 
    u22 = D2[2] 

    v20 = D2[3] 
    v21 = D2[4] 
    v22 = D2[5] 
    
    f0, f1, f2, h0, h1, h2, h3 = C[0], C[1], C[2], C[3], C[4], C[5], C[6]


# step 1

#  compute the inverse t1 of v1-v2 modulo u2
#  13M + 2SQ

    t10,t11,t12,res1 = modular_inverse_3n_2 (u20, u21, u22, v10-v20, v11-v21, v12-v22)

#  compute c=(u1-u2)t1
#  5M

    c0,c1,c2,c3,c4 = toom_cook_2_2 (u10-u20,u11-u21,u12-u22,t10,t11,t12)

# compute the remainder r of c by u2
#  4M
#Vorsicht: mit den Zeichen r0,r1,r2: die habe ich aus den anderen Implem. so uebernommen ...

    r2,r1,r0 = remainder_4_3n (c0, c1, c2, c3, c4, u20, u21, u22) 

# Solve the linear equation

#  5M + 1SQ

    tmp1 = res1 * (v12+v22) 
    tmp2 = v12**2 
    tmp3 = r0 * tmp2 
    tmp4 = r1 * tmp2 
    tmp5 = tmp3 * u22 
    gamma1_p =tmp1-(tmp4 - tmp5) 
    Gamma1 = gamma1_p * res1 

#  compute the part s of w= res1 r0 y**2 + s y + t with interpolation by 0 and 1:
#  8M

    tmp6  = res1 * r0 
    tmp7  = r0 * tmp3 
    tmp8  = r2 * gamma1_p 
    tmp9  = tmp7 * u20 
    tmp10 = tmp6 * (v10 + v20) 
    sval0 = tmp8 - tmp9 - tmp10 

    rval1  = r0 + r1 + r2 
    u2val1 = 1 + u22 + u21 + u20 
    v1val1 = v12 + v11 + v10 
    v2val1 = v22 + v21 + v20 

    tmp11 = rval1 * (tmp3 + gamma1_p) 
    tmp12 = tmp7 * u2val1 
    tmp13 = tmp6 * (v1val1 + v2val1) 

    sval1  = tmp11 - tmp12 - tmp13 

# s = s0 + s1 x
    s0 = sval0 
    s1 = sval1 - sval0 

# Compute Coeff(w,x,3) 
# 4M

    tmp14 = mulconst(tmp6 * v11, 2) 
    tmp15 = v12 * (s1 + tmp14) 
    tmp16 = tmp6 * tmp2 
    tmp17 = u12 * tmp16 
    coeff_w_x_3 = Gamma1 + tmp17 - tmp15 


# compute simultaneous inverse, such that the computing of the reultant should be easy and monic ...
# Cost :  if h3 == 0 ===> 2M + 1SQ + 1I
#         if h3 ne 0 ===> 8M + 2SQ + 1I

    tmp18    = tmp6 * coeff_w_x_3 
    tmp19    = tmp6**2 

    if h3 == 0 :
        inv = invert(tmp18) 
        coeffwx3_res1r0_m1 = inv 
        tmp20    = inv * coeff_w_x_3 
        res1r0m1 = tmp20 
    else:
        tmp20    = h3 * tmp19 
        tmp21    = h3 * ( -mulconst(tmp18,2) + tmp20) 
        tmp22    = coeff_w_x_3**2 
        B        = tmp22 + tmp21 
        tmp23    = tmp18 * B 
        inv      = invert(tmp23) 
        tmp24    = B * inv 
        coeffwx3_res1r0_m1 = tmp24 
        tmp25    = coeff_w_x_3 * coeffwx3_res1r0_m1 
        res1r0m1 = tmp25  
        tmp26    = inv * tmp18 

        Bm1      = tmp26 
        tmp27    = tmp22 * Bm1 
        Am1      = tmp27  
   # we use Am1 later, as we need to make the resltant monic.

#  Compute sy = sy1 x + sy 0 ( = s /( res1 r0))
#  2M

    tmp28 = s0 * res1r0m1  
    tmp29 = s1 * res1r0m1   
    sy0 = tmp28 
    sy1 = tmp29 

# Compute ty = u1 ( v12**2 x + gamma1) -v1 (v1 +sy) and tx = ty (res1 r0) **2 ( res1 r0 coeff(w,x,3) )**(-1)

# 12M
    tmp30 = Gamma1 * res1r0m1 
    gamma1 =  tmp30 
    tmp31 = u10 * gamma1 
    tmp32 = v10 * (v10 + sy0) 
    tmp33 = (1+ u12 + u11 + u10) * (tmp2 + gamma1) 
    tmp34 = (v12 + v11 + v10) * (v12 + v11 + v10 + sy1 + sy0) 
    tmp35 = (-1 + u12 - u11 + u10) * (- tmp2 + gamma1) 
    tmp36 = (v12 - v11 + v10) * (v12 - v11 + v10 - sy1 + sy0) 
    tmp37 = coeff_w_x_3 * res1r0m1 

    tyval0   = tmp31 - tmp32 
    tyval1   = tmp33 - tmp34 
    tyvalm1  = tmp35 - tmp36 
    tyvalinf = tmp37 

# for the following operation, no multiplication are necessary...
    ty0, ty1, ty2, ty3 = interpolate(tyval0, tyval1, tyvalm1, tyvalinf) 

    tmp38 = tmp19 * coeffwx3_res1r0_m1 
    tmp39 = ty0 * tmp38 
    tmp40 = ty1 * tmp38 
    tmp41 = ty2 * tmp38 

    tx0 = tmp39 
    tx1 = tmp40 
    tx2 = tmp41 

# Step 2:

# first coeff von tx**3 = x**9 + tx3_8 * x**8 + tx3_7 * x**7 + tx3_6 * x**6
# 1SQ + 1M

    tmp42 = tx2**2 
    tmp43 = tx2 * ( mulconst ( mulconst ( tx1,2 ) , 3 ) + tmp42 ) 
    tx3_8 = mulconst (tx2,3) 
    tx3_7 = mulconst ( tx1 + tmp42, 3 ) 
    tx3_6 = tmp43 + mulconst (tx0,3) 

# Berechnung von sy**2 = sy2_0 + sy2_1 * x + sy2_2 *x**2
#  3SQ

    tmp44 = sy1**2 
    tmp45 = (sy1 + sy0)**2 
    tmp46 = sy0**2 


    sy2_0 = tmp46 
    sy2_1 = (tmp45 - tmp44 - tmp46) 
    sy2_2 = tmp44 

# Computing of sy * ty = syty4 * x**4 + syty3 * x**3 + syty2 * x**2 + syty1 * x + syty0
# 5M
    syty0, syty1, syty2, syty3, syty4 = toom_cook_1_3 (sy0,sy1,ty0,ty1,ty2,ty3) 

# first coeff von sy**3 = sy3_3*x**3 + sy3_2 * x**2
# 2M

    tmp47 = sy1 * sy2_2 
    tmp48 = mulconst( sy2_2 * sy0, 3) 
    sy3_3 = tmp47 
    sy3_2 = tmp48 


#  Computing of H1= H18 * x**8  + H17 * x**7 + H16 * x**6 
#  1M

    tmp49 = (1 - mulconst( syty4 ,3 )) * f2 

    H18 = 1 - mulconst( syty4 ,3 )  
    H17 = sy3_3 - mulconst( syty3 ,3 ) 
    H16 = f2 + sy3_2 - mulconst( syty2 ,3 ) + tmp49 

# Computing H2:

    if ( h0 == 0 and h1 == 0 and h2 == 0 and h3 == 0) :
# Picard curves case:

        H23=0
        H24=0
        H25=0
        H26=0
        H27=0
        H28=0
        H29=0
        
    elif ( h1 == 0 and h2 == 0 and h3 == 0) :
        # h is a constant (h3=h2=h1=0 and h0 ne 9)
        # 1M + 1SQ
        tmp50 = - mulconst( ty3**2 , 2 ) 
        tmp51 = h0 * tmp50 
        H23=0 
        H24=0 
        H25=0 
        H26   = tmp51 
        H27=0  
        H28=0 
        H29=0 
    elif ( h2 == 0 and h3 == 0) :
        # h is linear
        # 6M
        P0,P1,P2 = toom_cook_1_1 (ty2, ty3, sy2_2 - mulconst( ty2, 2 ), - mulconst( ty3, 2 )) 
        H25,H26,H27 = toom_cook_1_1 (h0, h1, P1 + sy1, P2) 
        H23=0 
        H24=0 
        H28=0 
        H29=0 
    elif ( h3 == 0) :
        # h is quadratic
        # 10M
        P0,P1,P2,P3,P4 = toom_cook_2_2 (ty1, ty2, ty3, sy2_1 - mulconst( ty1, 2 ) + h1, sy2_2 - mulconst( ty2, 2 ) + h2, - mulconst( ty3, 2 )) 
        H24,H25,H26,H27,H28 = toom_cook_2_2 (h0, h1, h2,  P2 +sy0,  P3 +sy1, P4) 
        H29=0 
    else:
        # h is cubic
        # 15M
        P0,P1,P2,P3,P4,P5,P6 = toom_cook_3_3 (ty0, ty1, ty2, ty3, sy2_0 - 2* ty0 + h0, sy2_1 - 2* ty1 + h1, sy2_2 - 2* ty2 + h2, - 2 * ty3 + h3) 
        tmp52 = f2 * sy1 
        H23,H24,H25,H26,H27,H28,H29 = toom_cook_3_3 (h0, h1, h2, h3, P3 + tmp52 , P4 + sy0,  P5 + sy1, P6) 



# Berechnung der Resultante:
# resWC= (k1**3 *( H1 + H2 ) + tx**3) * Am1 , notice that Am1 is equal to 1 if deg(h) < 3!!!


#   1SQ  + 4M
    k1    = tmp38 
    tmp53 = k1**2 
    tmp54 = k1 * tmp53 

    tmp55 = tmp54 *( H16 + H26 ) 
    tmp56 = tmp54 *( H17 + H27 ) 
    tmp57 = tmp54 *( H18 + H28 ) 

    if h3 == 0 :
        ReswC6 = tmp55 + tx3_6 
        ReswC7 = tmp56 + tx3_7 
        ReswC8 = tmp57 + tx3_8 
        Am1=1 
    else:
   # 3M
        tmp58 = (tmp55 + tx3_6) * Am1 
        tmp59 = (tmp56 + tx3_7) * Am1 
        tmp60 = (tmp57 + tx3_8) * Am1 

        ReswC6 = tmp58 
        ReswC7 = tmp59 
        ReswC8 = tmp60 


# Computing the first term of U=u1*u2 = x**6 + U5*x**5 + U4*x**4 + U3 * x**3 + ....
# 3M
    tmp61 = u12 * u22 
    tmp62 = u12 * u21 
    tmp63 = u11 * u22 

    U5 = u12 + u22 
    U4 = u21 + u11 + tmp61 
    U3 = u20 + u10 + tmp62 + tmp63 

# 3M
    Um0, Um1, Um2 = quotient_6n_3n (ReswC6, ReswC7, ReswC8, U3, U4, U5) 

#  16M + 2SQ
    alpha10, alpha11, alpha12, res2 = modular_inverse_3n_3 (Um0, Um1, Um2, ty0 - sy2_0 - h0, ty1 - sy2_1 - h1, ty2 - sy2_2 - h2, ty3 - h3) 

# 4M
    Rem10,Rem11,Rem12= remainder_4_3n (syty0 - f0 , syty1 -f1, syty2 - f2, syty3, syty4 - 1 , Um0, Um1, Um2) 

#  5M
    Rem20,Rem21,Rem22,Rem23,Rem24= toom_cook_2_2 (Rem10,Rem11,Rem12,alpha10,alpha11,alpha12) 

# 4M
    fauxV12_0, fauxV12_1, fauxV12_2 = remainder_4_3n (Rem20 , Rem21, Rem22, Rem23, Rem24 , Um0, Um1, Um2) 

# 5M + 1I
    tmp64   = res2 *fauxV12_2 
    inv2    = invert(tmp64) 
    tmp65   = inv2*fauxV12_2 
    invres2 = tmp65 


    vD1D2_0 = invres2 * fauxV12_0 
    vD1D2_1 = invres2 * fauxV12_1 
    vD1D2_2 = invres2 * fauxV12_2 

# uD1D2=((inv2*res2**2*vD1D2)**3+(inv2*res2**2)**3*UnivariatePolynomial(f4)-(inv2*res2**2)**3*h1*vD1D2**2+(inv2*res2**2)**3*h2*vD1D2) div u_D1D2 
#  5M + 3SQ

    tmp66 = res2**2 
    tmp67 = inv2 * tmp66 
    tmp68 = tmp67**2 
    tmp69 = tmp68 * tmp67 
    tmp70 = tmp67 * vD1D2_1  
    tmp71 = tmp70**2  
    tmp72 = tmp67 * vD1D2_0  
    tmp73 = tmp70 * (tmp71 + mulconst ( mulconst ( tmp72 , 2), 3))  

    if ( h0 == 0 and h1 == 0 and h2 == 0 and h3 == 0) :
    # Picard curves case:

        tot5 = mulconst( tmp70, 3) 
        tot4 = mulconst(tmp72 + tmp71, 3) - tmp69 
        tot3 = tmp73 

    elif ( h1 == 0 and h2 == 0 and h3 == 0) :
        # h is a constant (h3=h2=h1=0 and h0 ne 9)

        tot5 = mulconst(tmp70, 3) 
        tot4 = mulconst(tmp72+ tmp71, 3) - tmp69 
        tot3 = tmp73 

    elif ( h2 == 0 and h3 == 0) :
        # h is linear
        #   2M
        tmp74 = h1 * vD1D2_2 
        tmp75 = tmp69 * tmp74  # coeff bei x**3

        tot5 = mulconst( tmp70, 3) 
        tot4 = mulconst(tmp72 + tmp71, 3) - tmp69 
        tot3 = tmp73 + tmp75 

    elif ( h3 == 0) :
        # h is quadratic
        # 5M
        tmp74, tmp75, tmp76 = toom_cook_1_1 (vD1D2_1,vD1D2_2,h1,h2) 
        tmp77 = tmp69 * tmp75  # coeff bei x**3
        tmp78 = tmp69 * tmp76  # coeff bei x**4

        tot5 = mulconst( tmp70, 3) 
        tot4 = mulconst( tmp72 + tmp71, 3) - tmp69 + tmp78 
        tot3 = tmp73 + tmp77 

    else:
        # h is cubic
        # 8M
        tmp74, tmp75, tmp76, tmp77, tmp78 = toom_cook_2_2 (vD1D2_0, vD1D2_1, vD1D2_2 , h1,h2, h3 ) 
        tmp79 = tmp69 * tmp76  # coeff bei x**3
        tmp80 = tmp69 * tmp77  # coeff bei x**4
        tmp81 = tmp69 * tmp78  # coeff bei x**5

        tot5 = mulconst( tmp70, 3) + tmp81 
        tot4 = mulconst( tmp72+ tmp71, 3) - tmp69 +tmp80 
        tot3 = tmp73 + tmp79 


# 3M
    UD1D2_0, UD1D2_1, UD1D2_2 = quotient_6n_3n (tot3, tot4, tot5, Um0, Um1, Um2) 

    return [UD1D2_0, UD1D2_1, UD1D2_2, vD1D2_0, vD1D2_1, vD1D2_2] 


def double (D1, C):

    u10 = D1[0] 
    u11 = D1[1] 
    u12 = D1[2] 

    v10 = D1[3] 
    v11 = D1[4] 
    v12 = D1[5] 
    
    f0, f1, f2, h0, h1, h2, h3 = C[0], C[1], C[2], C[3], C[4], C[5], C[6]
# step 1
#  compute v1**3 + v1 *h - f =  v1 * ( v1**2 + h ) - f

# First compute v1**2

    v1val1 = v12 + v11 + v10 
    v1valm1 = v12 - v11 + v10 
    v1val2 = mulconst (v12, 4) + mulconst (v11, 2) + v10 

# 5SQ
    v2_0, v2_1, v2_2, v2_3, v2_4 = toom_cook_square_2 (v10,v11,v12) 

# Compute the 4 highest coefficients of
# v1 * (v1**2 + h) - f into a variable b.
# For this S (4, 3  4), perform first Toom-Cook on the 3 highest
# coefficients.

# 6M
    b1,b2,b3,b4,b5,b6 =toom_cook_2_3 (v10, v11, v12, v2_1 + h1, v2_2 + h2, v2_3 + h3, v2_4 ) 

# correct:

    b4=  b4 - 1 

# Perform an exact division by u1 to obtain w1.
# 6M

    w13 = b6 
    w12 = b5 - w13 * u12 
    w11 = b4 - w13 * u11 - w12 * u12 
    w10 = b3 - w13 * u10 - w12 * u11 - w11 * u12 

#  compute the inverse t1 of w1 modulo u1
#  with the Euclidian algorithm between c = w1 and u1
#  16M + 2SQ

    t10,t11,t12,res1 = modular_inverse_3n_3 (u10, u11, u12, w10, w11, w12, w13) 


#  compute Remainder ( 3 v1**2 + h, u1)
#  4M

    Rem1_0 ,Rem1_1, Rem1_2 = remainder_4_3n ( mulconst( v2_0,3) + h0, mulconst( v2_1, 3) + h1 , mulconst( v2_2, 3) + h2, mulconst( v2_3, 3) + h3, mulconst( v2_4,3), u10, u11, u12) 

# 5M
    c0,c1,c2,c3,c4 = toom_cook_2_2 (Rem1_0, Rem1_1 , Rem1_2 , t10 , t11 , t12) 

# compute the remainder r of c by u1
#  4M
#Vorsicht: mit den Zeichen r0,r1,r2: die habe ich aus den anderen Implem. so uebernommen ...

    r2,r1,r0 = remainder_4_3n (c0, c1, c2, c3, c4, u10, u11, u12) 


# Solve the linear equation

#  5M

    tmp1 = mulconst( res1 * v12, 2) 
    tmp2 = v2_4 
    tmp3 = r0 * tmp2 
    tmp4 = r1 * tmp2 
    tmp5 = tmp3 * u12 
    gamma1_p =tmp1-(tmp4 - tmp5) 
    Gamma1 = gamma1_p * res1 

#  compute the part s of w= res1 r0 y**2 +s y + t with interpolation by 0 and 1:
#  8M

    tmp6  = res1 * r0 
    tmp7  = r0 * tmp3 
    tmp8  = r2 * gamma1_p 
    tmp9  = tmp7 * u10 
    tmp10 = mulconst( tmp6 * v10, 2) 
    sval0 = tmp8 - tmp9 - tmp10 

    rval1  = r0 + r1 + r2 
    u1val1 = 1 + u12 + u11 + u10 
    v1val1 = v12 + v11 + v10 

    tmp11 = rval1 * (tmp3 + gamma1_p) 
    tmp12 = tmp7 * u1val1 
    tmp13 = mulconst( tmp6 * v1val1, 2) 

    sval1  = tmp11 - tmp12 - tmp13 

# s = s0 + s1 x
    s0 = sval0 
    s1 = sval1 - sval0 

# Compute Coeff(w,x,3) 
# 4M

    tmp14 = mulconst(tmp6 * v11, 2) 
    tmp15 = v12 * (s1 + tmp14) 
    tmp16 = tmp6 * tmp2 
    tmp17 = u12 * tmp16 
    coeff_w_x_3 = Gamma1 + tmp17 - tmp15 


# compute simultaneous inverse, such that the computing of the reultant should be easy and monic ...
# Cost :  if h3 == 0 ===> 2M + 1SQ + 1I
#         if h3 ne 0 ===> 8M + 2SQ + 1I

    tmp18    = tmp6 * coeff_w_x_3 
    tmp19    = tmp6**2 

    if h3 == 0 :
        inv      = invert(tmp18) 
        coeffwx3_res1r0_m1 = inv 
        tmp20    = inv * coeff_w_x_3 
        res1r0m1 = tmp20 
    else:
        tmp20    = h3 * tmp19 
        tmp21    = h3 * ( -mulconst(tmp18,2) + tmp20) 
        tmp22    = coeff_w_x_3**2 
        B        = tmp22 + tmp21 
        tmp23    = tmp18 * B 
        inv      = invert(tmp23) 
        tmp24    = B * inv 
        coeffwx3_res1r0_m1 = tmp24 
        tmp25    = coeff_w_x_3 * coeffwx3_res1r0_m1 
        res1r0m1 = tmp25  
        tmp26    = inv * tmp18 

        Bm1      = tmp26 
        tmp27    = tmp22 * Bm1 
        Am1      = tmp27  
   # we use Am1 later, as we need to make the resultant monic.


#  Compute sy = sy1 x + sy 0 ( = s /( res1 r0))
#  2M

    tmp28 = s0 * res1r0m1  
    tmp29 = s1 * res1r0m1   
    sy0 = tmp28 
    sy1 = tmp29 

# Compute ty = u1 ( v12**2 x + gamma1) -v1 (v1 +sy) and tx = ty (res1 r0) **2 ( res1 r0 coeff(w,x,3) )**(-1)
# 12M

    tmp30 = Gamma1 * res1r0m1 
    gamma1 =  tmp30 
    tmp31 = u10 * gamma1 
    tmp32 = v10 * (v10 + sy0) 
    tmp33 = (1+ u12 + u11 + u10) * (tmp2 + gamma1) 
    tmp34 = (v12 + v11 + v10) * (v12 + v11 + v10 + sy1 + sy0) 
    tmp35 = (-1 + u12 - u11 + u10) * (- tmp2 + gamma1) 
    tmp36 = (v12 - v11 + v10) * (v12 - v11 + v10 - sy1 + sy0) 
    tmp37 = coeff_w_x_3 * res1r0m1 

    tyval0   = tmp31 - tmp32 
    tyval1   = tmp33 - tmp34 
    tyvalm1  = tmp35 - tmp36 
    tyvalinf = tmp37 

# for the following operation, no multiplication are necessary...

    ty0, ty1, ty2, ty3 = interpolate(tyval0, tyval1, tyvalm1, tyvalinf) 


    tmp38 = tmp19 * coeffwx3_res1r0_m1 
    tmp39 = ty0 * tmp38 
    tmp40 = ty1 * tmp38 
    tmp41 = ty2 * tmp38 

    tx0 = tmp39 
    tx1 = tmp40 
    tx2 = tmp41 

# Step 2:

# first coeff von tx**3 = x**9 + tx3_8 * x**8 + tx3_7 * x**7 + tx3_6 * x**6
# 1SQ + 1M

    tmp42 = tx2**2 
    tmp43 = tx2 * ( mulconst ( mulconst ( tx1,2 ) , 3 ) + tmp42 ) 
    tx3_8 = mulconst (tx2,3) 
    tx3_7 = mulconst ( tx1 + tmp42, 3 ) 
    tx3_6 = tmp43 + mulconst (tx0,3) 


# Berechnung von sy**2 = sy2_0 + sy2_1 * x + sy2_2 *x**2
#  3SQ

    tmp44 = sy1**2 
    tmp45 = (sy1 + sy0)**2 
    tmp46 = sy0**2 


    sy2_0 = tmp46 
    sy2_1 = (tmp45 - tmp44 - tmp46) 
    sy2_2 = tmp44

# Computing of sy * ty = syty4 * x**4 + syty3 * x**3 + syty2 * x**2 + syty1 * x + syty0
# 5M
    syty0, syty1, syty2, syty3, syty4 = toom_cook_1_3 (sy0,sy1,ty0,ty1,ty2,ty3) 


# first coeff von sy**3 = sy3_3*x**3 + sy3_2 * x**2
# 2M

    tmp47 = sy1 * sy2_2 
    tmp48 = mulconst( sy2_2 * sy0, 3) 
    sy3_3 = tmp47 
    sy3_2 = tmp48 


#  Computing of H1= H18 * x**8  + H17 * x**7 + H16 * x**6 
#  1M

    tmp49 = (1 - mulconst( syty4 ,3 )) * f2 

    H18 = 1 - mulconst( syty4 ,3 )  
    H17 = sy3_3 - mulconst( syty3 ,3 ) 
    H16 = f2 + sy3_2 - mulconst( syty2 ,3 ) + tmp49 

# Computing H2:


    if ( h0 == 0 and h1 == 0 and h2 == 0 and h3 == 0) :
    # Picard curves case:

        H23=0 
        H24=0 
        H25=0
        H26=0
        H27=0
        H28=0
        H29=0 
        
    elif ( h1 == 0 and h2 == 0 and h3 == 0) :
        # h is a constant (h3=h2=h1=0 and h0 ne 9)
        # 1M + 1SQ
        tmp50 = - mulconst( ty3**2 , 2 ) 
        tmp51 = h0 * tmp50 
        H23=0 
        H24=0 
        H25=0 
        H26   = tmp51 
        H27=0  
        H28=0 
        H29=0 
    elif ( h2 == 0 and h3 == 0) :
        # h is linear
        # 6M
        P0,P1,P2 = toom_cook_1_1 (ty2, ty3, sy2_2 - mulconst( ty2, 2 ), - mulconst( ty3, 2 )) 
        H25,H26,H27 = toom_cook_1_1 (h0, h1, P1 + sy1, P2) 
        H23=0 
        H24=0 
        H28=0 
        H29=0 
    elif ( h3 == 0) :
        # h is quadratic
        # 10M
        P0,P1,P2,P3,P4 = toom_cook_2_2 (ty1, ty2, ty3, sy2_1 - mulconst( ty1, 2 ) + h1, sy2_2 - mulconst( ty2, 2 ) + h2, - mulconst( ty3, 2 )) 
        H24,H25,H26,H27,H28 = toom_cook_2_2 (h0, h1, h2,  P2 +sy0,  P3 +sy1, P4) 
        H29=0 
    else:
        # h is cubic
        # 15M
        P0,P1,P2,P3,P4,P5,P6 = toom_cook_3_3 (ty0, ty1, ty2, ty3, sy2_0 - mulconst(ty0,2) + h0, sy2_1 - mulconst(ty1,2) + h1, sy2_2 - mulconst(ty2,2) + h2, - mulconst(ty3, 2) + h3) 
        tmp52 = f2 * sy1 
        H23,H24,H25,H26,H27,H28,H29 = toom_cook_3_3 (h0, h1, h2, h3, P3 + tmp52 , P4 + sy0,  P5 + sy1, P6) 


# Berechnung der Resultante:
# resWC= (k1**3 *( H1 + H2 ) + tx**3) * Am1 , notice that Am1 is ==ual to 1 if deg(h) < 3!!!

#   4M + 1SQ

    k1    = tmp38 
    tmp53 = k1**2 
    tmp54 = k1 * tmp53 

    tmp55 = tmp54 *( H16 + H26 ) 
    tmp56 = tmp54 *( H17 + H27 ) 
    tmp57 = tmp54 *( H18 + H28 ) 

    if h3 == 0 :
        ReswC6 = tmp55 + tx3_6 
        ReswC7 = tmp56 + tx3_7 
        ReswC8 = tmp57 + tx3_8 
        Am1=1 
    else:
        # 3M
        tmp58 = (tmp55 + tx3_6) * Am1 
        tmp59 = (tmp56 + tx3_7) * Am1 
        tmp60 = (tmp57 + tx3_8) * Am1 

        ReswC6 = tmp58 
        ReswC7 = tmp59 
        ReswC8 = tmp60  


# Computing the first term of U=u1*u2 = x**6 + U5*x**5 + U4*x**4 + U3 * x**3 + ....

# 1M + 1SQ

    tmp61 = u12**2 
    tmp62 = u12 * u11 
    tmp63 = tmp62 

    U5 = mulconst(u12, 2) 
    U4 = mulconst(u11,2) + tmp61 
    U3 = mulconst(u10,2) + tmp62 + tmp63 

# 3M
    Um0, Um1, Um2 = quotient_6n_3n (ReswC6, ReswC7, ReswC8, U3, U4, U5) 

# 16M + 2SQ
    alpha10, alpha11, alpha12, res2 = modular_inverse_3n_3 (Um0, Um1, Um2, ty0 - sy2_0 - h0, ty1 - sy2_1 - h1, ty2 - sy2_2 - h2, ty3 - h3) 

# 4M
    Rem10,Rem11,Rem12= remainder_4_3n (syty0 - f0 , syty1 -f1, syty2 - f2, syty3, syty4 - 1 , Um0, Um1, Um2) 

# 5M
    Rem20,Rem21,Rem22,Rem23,Rem24= toom_cook_2_2 (Rem10,Rem11,Rem12,alpha10,alpha11,alpha12) 

# 4M
    fauxV12_0, fauxV12_1, fauxV12_2 = remainder_4_3n (Rem20 , Rem21, Rem22, Rem23, Rem24 , Um0, Um1, Um2) 

# 5M + 1I

    tmp64   = (res2 *fauxV12_2) 
    inv2    = invert(tmp64) 
    tmp65   = inv2*fauxV12_2 
    invres2 = tmp65 


    vD1D2_0 = invres2 * fauxV12_0 
    vD1D2_1 = invres2 * fauxV12_1 
    vD1D2_2 = invres2 * fauxV12_2 

# uD1D2=((inv2*res2**2*vD1D2)**3+(inv2*res2**2)**3*UnivariatePolynomial(f4)-(inv2*res2**2)**3*h1*vD1D2**2+(inv2*res2**2)**3*h2*vD1D2) div u_D1D2 

#  5M + 3SQ

    tmp66 = res2**2 
    tmp67 = inv2*tmp66 
    tmp68 = tmp67**2 
    tmp69 = tmp68*tmp67 
    tmp70 = tmp67 * vD1D2_1  
    tmp71 = tmp70**2  
    tmp72 = tmp67 * vD1D2_0  
    tmp73 = tmp70 * (tmp71 + mulconst ( mulconst ( tmp72 , 2), 3))  

    if ( h0 == 0 and h1 == 0 and h2 == 0 and h3 == 0) :
        # Picard curves case:

        tot5 = mulconst( tmp70, 3) 
        tot4 = mulconst(tmp72 + tmp71, 3) - tmp69 
        tot3 = tmp73 

    elif ( h1 == 0 and h2 == 0 and h3 == 0) :
        # h is a constant (h3=h2=h1=0 and h0 ne 9)

        tot5 = mulconst(tmp70, 3) 
        tot4 = mulconst(tmp72+ tmp71, 3) - tmp69 
        tot3 = tmp73 

    elif ( h2 == 0 and h3 == 0) :
        # h is linear
        # 2M
        tmp74 = h1 * vD1D2_2 
        tmp75 = tmp69 * tmp74  # coeff bei x**3

        tot5 = mulconst(tmp70,3) 
        tot4 = mulconst(tmp72+ tmp71, 3) - tmp69 
        tot3 = tmp73 + tmp75 

    elif ( h3 == 0) :
        # h is quadratic
        # 5M
        tmp74, tmp75, tmp76 = toom_cook_1_1 (vD1D2_1,vD1D2_2,h1,h2) 
        tmp77 = tmp69 * tmp75  # coeff bei x**3
        tmp78 = tmp69 * tmp76  # coeff bei x**4

        tot5 = mulconst( tmp70, 3) 
        tot4 = mulconst( tmp72+ tmp71, 3) - tmp69 + tmp78 
        tot3 = tmp73 + tmp77 

    else:
        # h is cubic
        # 8M
        tmp74, tmp75, tmp76, tmp77, tmp78 = toom_cook_2_2 (vD1D2_0, vD1D2_1, vD1D2_2 , h1,h2, h3 ) 
        tmp79 = tmp69 * tmp76  # coeff bei x**3
        tmp80 = tmp69 * tmp77  # coeff bei x**4
        tmp81 = tmp69 * tmp78  # coeff bei x**5

        tot5 = mulconst( tmp70, 3) + tmp81 
        tot4 = mulconst( tmp72+ tmp71, 3) - tmp69 +tmp80 
        tot3 = tmp73 + tmp79 


# 3M
    UD1D2_0, UD1D2_1, UD1D2_2 = quotient_6n_3n (tot3, tot4, tot5, Um0, Um1, Um2) 

    return [UD1D2_0, UD1D2_1, UD1D2_2, vD1D2_0, vD1D2_1, vD1D2_2]
